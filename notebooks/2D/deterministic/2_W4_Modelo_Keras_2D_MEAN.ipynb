# %% [markdown]
# # Prueba Modelo con Data Augmentacion:
# - Proceso de lectura a través de TF.
# - Adicional se vuelve a tomar la parte de la lectura de los CTs una sola vez.

# %% [markdown]
# # Modelo.
# - Limitación pixeles de -1000 a 0
# - Prueba ventana parénquima pulmonar desde W3. Para ver si hay algo raro en el script.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install volumentations-3D
# !pip install keras-tuner --upgrade
# !pip install keras_applications
# !pip install tensorflow==2.11.0
# !pip install keras==2.11.0
# Out:
# Requirement already satisfied: volumentations-3D in /usr/local/lib/python3.10/dist-packages (1.0.4)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from volumentations-3D) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from volumentations-3D) (1.11.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from volumentations-3D) (4.8.0.76)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from volumentations-3D) (1.25.2)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->volumentations-3D) (3.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->volumentations-3D) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->volumentations-3D) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->volumentations-3D) (2024.4.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->volumentations-3D) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->volumentations-3D) (24.0)

# %%
# Tratamiento datos
import pandas as pd
import numpy as np
from collections import Counter
import time

# Organizar rutas imágenes
import os
import random

# Lectura tomografías.
import nibabel as nib # Lectura
from scipy import ndimage # Tratamiento

# Modelado
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Data Augmentation
from volumentations import *

# Visualización CTs
import matplotlib.pyplot as plt
import re

import itertools
from functools import partial

pd.set_option('display.max_columns', 500)
pd.set_option('display.float_format', lambda x: f'{x:.3f}')
#pd.set_option('display.float_format', lambda x: f'{x:,.3f}') #add a comma separator between the thousands.
pd.set_option('display.max_colwidth',1000)



np.set_printoptions(threshold=1000, linewidth = 300, edgeitems = 5)
np.set_printoptions(suppress=True)


import pickle

# %% [markdown]
# # Parámetros

# %%
ambiente = 'GOOGLE' # 'GOOGLE' o 'LOCAL'
reduccion = "MEAN" # SUM o MEAN
reading_cts_tf = False
version_modelo = "Keras_Arch_W4_V1_Optimizado_2D_MEAN" # CAMBIAR!!!!!!!!!!!!!!!!!!!!!!!!!!

# Ventana Parénquima Pulmonar
min_ventana = -1000
max_ventana = 0

# Rutas Datasets
ruta_dfs_google = r'/content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Path_Sets/'
ruta_dfs_local = r'G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Path_Sets/'

ruta_modelo_google = r'/content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/'
ruta_modelo_local = r'G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Modelos/'

# Rutas
if ambiente == 'GOOGLE':
    print("Rutas DFs")
    ruta_dfs = ruta_dfs_google

    print("El modelo se guardará en Modelos_Colab")
    ruta_modelo = ruta_modelo_google
    file_modelo = r'{}Modelo_{}.h5'.format(ruta_modelo_google,version_modelo)
    file_history = r'{}History_Modelo_{}'.format(ruta_modelo_google,version_modelo)

else:
    print("Rutas DFs")
    ruta_dfs = ruta_dfs_local

    print("El modelo se guardará en Modelos")
    ruta_modelo = ruta_modelo_local
    file_modelo = r'{}Modelo_{}.h5'.format(ruta_modelo_local,version_modelo)
    file_history = r'{}History_Modelo_{}'.format(ruta_modelo_local,version_modelo)

# Validando rutas
if os.path.exists(ruta_modelo):
    print("Existe ruta guardado modelo.")
    print(f"El modelo se guardará en: {file_modelo}")
else:
    print("Creando ruta para modelos!!!!!!! ")
    os.makedirs(ruta_modelo)

print(ruta_modelo)

# Parámetros Redes:
BATCH_SIZE=2
RANDOM = 9411
initial_learning_rate = 0.0001
epochs = 150
# Out:
# Rutas DFs
# El modelo se guardará en Modelos_Colab
# Existe ruta guardado modelo.
# El modelo se guardará en: /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MEAN.h5
# /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/

# %% [markdown]
# # Lectura Imágenes

# %% [markdown]
# ## Rutas

# %%
if ambiente == 'GOOGLE':
    print("Leyendo rutas de google")
    train_df = pd.read_csv(ruta_dfs + 'train_df.csv')
    test_df = pd.read_csv(ruta_dfs + 'test_df.csv')
    valid_df = pd.read_csv(ruta_dfs + 'valid_df.csv')

    train_df['path'] = train_df['File_Path_Google']
    test_df['path'] = test_df['File_Path_Google']
    valid_df['path'] = valid_df['File_Path_Google']

else:
    print("Leyendo rutas del local")
    train_df = pd.read_csv(ruta_dfs + 'train_df.csv')
    test_df = pd.read_csv(ruta_dfs + 'test_df.csv')
    valid_df = pd.read_csv(ruta_dfs + 'valid_df.csv')

    train_df['path'] = train_df['File_Path']
    test_df['path'] = test_df['File_Path']
    valid_df['path'] = valid_df['File_Path']
# Out:
# Leyendo rutas de google

# %%
# train_df = pd.DataFrame({'path' : ['/content/data/study_0001.nii.gz',
#                                    '/content/data/study_0002.nii.gz',
#                                    '/content/data/study_0003.nii.gz',
#                                    '/content/data/study_0004.nii.gz']})
# train_df['Label'] = 0

# valid_df = pd.DataFrame({'path' : ['/content/data/study_0003.nii.gz',
#                                    '/content/data/study_0004.nii.gz',
#                                    '/content/data/study_0005.nii.gz']})
# valid_df['Label'] = 0

# test_df = valid_df.copy()


# train_df

# %%
valid_df.head()
# Out:
#                                                                   File_Path  \
# 0  G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0026.nii.gz
# 1  G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0031.nii.gz
# 2  G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0180.nii.gz
# 3  G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0075.nii.gz
# 4  G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0139.nii.gz
#
#                                                                       File_Path_Google  \
# 0  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0026.nii.gz
# 1  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0031.nii.gz
# 2  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0180.nii.gz
# 3  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0075.nii.gz
# 4  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0139.nii.gz
#
#    Label  \
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#
#                                                                                   path
# 0  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0026.nii.gz
# 1  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0031.nii.gz
# 2  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0180.nii.gz
# 3  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0075.nii.gz
# 4  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0139.nii.gz

# %% [markdown]
# ## Lectura:

# %%
def read_nifti_file(filepath):
    """Read and load volume"""
    # Read file
    scan = nib.load(filepath)
    # Get raw data
    scan = scan.get_fdata(caching='unchanged')
    return scan


def normalize(volume, min_normalize, max_normalize):
  """Normalize the volume"""
  min = min_normalize #-1000
  max = max_normalize #400
  volume[volume < min] = min
  volume[volume > max] = max
  volume = (volume - min) / (max - min)
  volume = volume.astype("float32")
  return volume


def resize_volume(img):
  # Esta conversión de 3D a 2D se puede hacer antes o después del zoom.
  if reduccion == 'SUM':
    # Sumamos la 3ra dimensión.
    img = np.sum(img,axis=-1)
  if reduccion == 'MEAN':
    # Promediamos la 3ra dimensión.
    img = np.mean(img,axis=-1)
  if reduccion == 'MAX':
    # Promediamos la 3ra dimensión.
    img = np.max(img,axis=-1)

  """Resize across z-axis"""
  # Set the desired depth
  desired_width = 128
  desired_height = 128
  # Get current depth
  current_width = img.shape[0]
  current_height = img.shape[1]
  # Compute depth factor
  width = current_width / desired_width
  height = current_height / desired_height
  width_factor = 1 / width
  height_factor = 1 / height

  # Resize across z-axis
  tic = time.time()
  img = ndimage.zoom(img, (width_factor, height_factor), order=1)
  #print("     Tiempo zoom:",time.time() - tic)

  # Rotate
  tic = time.time()
  img = ndimage.rotate(img, 90, reshape=False)
  #print("     Tiempo rotate:",time.time() - tic)

  return img

# %%
def rotate(volume):
    # define some rotation angles
    angles = [-20, -10, -5, 5, 10, 20]
    # pick angles at random
    angle = random.choice(angles)
    # rotate volume
    volume = ndimage.rotate(volume, angle, reshape=False)
    volume[volume < 0] = 0
    volume[volume > 1] = 1
    return volume

# %%
def get_augmentation(patch_size):
    return Compose([
        #Resize(patch_size, interpolation=1, resize_type=0, always_apply=True, p=1.0),
        Flip(0, p=1), # Eje X
        Flip(1, p=1), # Eje Y
        Flip(2, p=1), # Eje Z
        GaussianNoise(var_limit=(0.0001, 0.0005), p=1),
        ColorJitter(brightness=(1,3),contrast=(0.4,0.8),saturation=0,hue=0, p=1),
    ], p=1)

def augmentor(img):
    aug = get_augmentation((128,128,64))
    data = {'image': img}
    aug_data = aug(**data)
    img = aug_data['image']
    return np.ndarray.astype(img , np.float32)

# %%
def load_arrays(path, training_):

    #print(path.numpy().decode())
    tic1 = time.time()

    # Lectura CT
    tic = time.time()
    image_ = nib.load(path.numpy().decode())
    #print("Tiempo lectura:",time.time() - tic)

    # Convertirlo en array
    tic = time.time()
    image_ = image_.get_fdata()
    #print("shape:",image_.shape)
    #print("Tiempo array:",time.time() - tic)

    # Aplicar función de estandarización número de cortes y rotación 90 grados
    tic = time.time()
    image = resize_volume(image_)[..., None]
    #print("Tiempo resize:",time.time() - tic)

    # Aplicar función normalización
    tic = time.time()
    image = normalize(image, min_normalize=min_ventana, max_normalize=max_ventana)
    #print("Tiempo normalizacion:",time.time() - tic)

    if training_:
        #print("Aplicando Data Augmentation************************************")

        # Aplicar rotación aleatoria
        tic = time.time()
        image = rotate(image)
        #print("Tiempo rotación aleatoria:",time.time() - tic)

        # Implementar data augmentation
        tic = time.time()
        #image = augmentor(image)
        #print("Tiempo aug:",time.time() - tic)

        # Limitando valores entre 0-1
        tic = time.time()
        #image = tf.clip_by_value(image, clip_value_min = 0, clip_value_max = 1)
        #print("Tiempo clip_by_value:",time.time() - tic)

    else:
        #print("Las tomografías se cargan solo con el resize y la normalización")

        #print("|| Tiempo total lectura tomografía: ", time.time() - tic1)
        #print("---")

        image = image


    return image#.reshape(image_.shape+(1,))

def tf_data_array(filenames1, labels, training_):
    [image,] = tf.py_function(func= load_arrays,  inp=[filenames1, training_], Tout=[tf.float32])
    image.set_shape((128,128,1))
    return image,  labels

# %%
def datasets_iteration(dataset_row, training=False):
    filename = dataset_row['path']
    labels = dataset_row['Label']
    dataset = tf.data.Dataset.from_tensor_slices((filename,labels))

    #print(dataset)

    if training:
        dataset = dataset.shuffle(len(dataset_row),seed=RANDOM)

    #Aplicamos todas las funciones de pre-procesamiento
    #dataset = dataset.map(tf_data_array).batch(BATCH_SIZE)#.prefetch(tf.data.AUTOTUNE)
    # dataset = dataset.map(tf_data_array).cache().batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    # dataset = dataset.map(tf_data_array, num_parallel_calls = 4).batch(BATCH_SIZE).cache().prefetch(tf.data.AUTOTUNE)
    # dataset = dataset.map(tf_data_array, num_parallel_calls = 4).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    # dataset = dataset.map(tf_data_array, num_parallel_calls = 4).batch(BATCH_SIZE).prefetch(1)
    dataset = dataset.map(partial(tf_data_array, training_ = training), num_parallel_calls = tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(2)

    # https://stackoverflow.com/questions/59228816/what-do-the-tensorflow-datasets-functions-cache-and-prefetch-do
    # https://stackoverflow.com/questions/63796936/what-is-the-proper-use-of-tensorflow-dataset-prefetch-and-cache-options
    # https://cs230.stanford.edu/blog/datapipeline/#best-practices
    return dataset

# %%
train_dataset = datasets_iteration(train_df,True)
test_dataset = datasets_iteration(test_df)
validation_dataset = datasets_iteration(valid_df)

# train_dataset = datasets_iteration(train_df.iloc[[5,6,7,8,9,290,291,292,293,294]],True)
# test_dataset = datasets_iteration(test_df.iloc[[5,6,7,8,9,79,80,81,82,83]])
# validation_dataset = datasets_iteration(valid_df.iloc[[5,6,7,8,9,40,41,42,43,44]])

# %%
validation_dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %% [markdown]
# ### Método una sola lectura

# %%
def process_scan(path, min_normalize, max_normalize):
    """Read and resize volume"""
    # Read scan
    volume = read_nifti_file(path)
    # Resize width, height and depth
    volume = resize_volume(volume)[..., None]
    # Normalize
    volume = normalize(volume, min_normalize=min_normalize, max_normalize=max_normalize)

    return volume

def data_augmentation(volume, training_):

    if training_:

        #print("Aplicando Data Augmentation************************************")

        # Aplicar rotación aleatoria
        tic = time.time()
        volume = rotate(volume)
        #print("Tiempo rotación aleatoria:",time.time() - tic)

        # Implementar data augmentation
        tic = time.time()
        # volume = augmentor(volume)
        #print("Tiempo aug:",time.time() - tic)

        # Limitando valores entre 0-1
        tic = time.time()
        # volume = tf.clip_by_value(volume, clip_value_min = 0, clip_value_max = 1)
        #print("Tiempo clip_by_value:",time.time() - tic)

    else:
        volume = volume

    return volume


def tf_data_array2(images, labels, training_):
    [image,] = tf.py_function(func= data_augmentation,  inp=[images, training_], Tout=[tf.float32])
    image.set_shape((128,128,1))
    return image,  labels

# %%
if reading_cts_tf == False:
  print("Leyendo CTs una sola vez")
  # Leyendo tomografías de entrenamiento
  print("Leyendo tomografías de entrenamiento")
  tic = time.time()
  x_train = np.array([process_scan(path, min_normalize= min_ventana, max_normalize=max_ventana) for path in train_df['path']])
  print("--- %s minutos ---" % ((time.time() - tic)/60))

  print("Leyendo tomografías de test")
  tic = time.time()
  x_test = np.array([process_scan(path, min_normalize= min_ventana, max_normalize=max_ventana) for path in test_df['path']])
  print("--- %s minutos ---" % ((time.time() - tic)/60))

  print("Leyendo tomografías de validación")
  tic = time.time()
  x_valid = np.array([process_scan(path, min_normalize= min_ventana, max_normalize=max_ventana) for path in valid_df['path']])
  print("--- %s minutos ---" % ((time.time() - tic)/60))
# Out:
# Leyendo CTs una sola vez
# Leyendo tomografías de entrenamiento
# --- 1.046351703008016 minutos ---
# Leyendo tomografías de test
# --- 0.28799646298090614 minutos ---
# Leyendo tomografías de validación
# --- 0.14780720472335815 minutos ---

# %%
# Validación Dimensión Arrays:
print(f"Dim x_train: {x_train.shape} -- Dim y_train: {len(train_df['path'])}. -- {Counter(train_df['Label'])}")
print(f"Dim x_train: {x_test.shape} -- Dim y_train: {len(test_df['path'])}. -- {Counter(test_df['Label'])}")
print(f"Dim x_train: {x_valid.shape} -- Dim y_train: {len(valid_df['path'])}. -- {Counter(valid_df['Label'])}")
# Out:
# Dim x_train: (295, 128, 128, 1) -- Dim y_train: 295. -- Counter({0: 177, 1: 118})
# Dim x_train: (84, 128, 128, 1) -- Dim y_train: 84. -- Counter({0: 50, 1: 34})
# Dim x_train: (45, 128, 128, 1) -- Dim y_train: 45. -- Counter({0: 27, 1: 18})

# %%
def datasets_iteration2(images, dataset_row, training=False):

    labels = dataset_row['Label']

    dataset = tf.data.Dataset.from_tensor_slices((images,labels))

    if training:
        dataset = dataset.shuffle(len(images),seed=RANDOM)

    dataset = dataset.map(partial(tf_data_array2, training_ = training), num_parallel_calls = tf.data.AUTOTUNE).batch(BATCH_SIZE)#.prefetch(1)

    #dataset = dataset.batch(BATCH_SIZE).prefetch(2)

    return dataset

# %%
if reading_cts_tf == False:
  print("Datasets creados con datasets_iteration2 ************")
  train_dataset = datasets_iteration2(x_train, train_df,True)
  test_dataset = datasets_iteration2(x_test, test_df)
  validation_dataset = datasets_iteration2(x_valid, valid_df)
else:
  print("Se mantiene el objeto TF para lectura de CTs según el batch")
# Out:
# Datasets creados con datasets_iteration2 ************

# %%
validation_dataset
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %% [markdown]
# ## Visualizamos algunas imágenes

# %% [markdown]
# ### Train

# %%
tic = time.time()
data = train_dataset.take(1) # Tomamos primer batch
data2 = list(data)

images, labels = data2[0]
images = images.numpy()
print("******* Tiempo total lectura batch: ", time.time() - tic)
# Out:
# ******* Tiempo total lectura batch:  0.04215359687805176

# %%
index_ct = 0
mensaje = f"CT Etiqueta: {labels.numpy()[index_ct]} "
print(mensaje)
img_print = images[index_ct]
label_print = labels.numpy()[index_ct]
fig = plt.figure(figsize=(10, 5))
columns = 10
rows = 7
depth_img = img_print.shape[2]

file_image_path = f'G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Imgs/TF_VF_Index{index_ct}_Rango{min_ventana}_{max_ventana}.png'
print(file_image_path)

plt.imshow(img_print)

# # ax enables access to manipulate each of subplots
# ax = []

# for i in range(1, depth_img+1):
#     img = np.squeeze(img_print[:, :, i-1])
#     #fig.add_subplot(rows, columns, i)
#     ax.append( fig.add_subplot(rows, columns, i))
#     ax[-1].set_title("depth:"+str(i))  # set title
#     plt.imshow(img, cmap='gray')
# plt.suptitle(mensaje)
# #plt.savefig(file_image_path)
# plt.show()
# Out:
# CT Etiqueta: 1
# G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Imgs/TF_VF_Index0_Rango-1000_0.png

# %% [markdown]
# ### Valid

# %%
tic = time.time()
data = validation_dataset.take(1) # Tomamos primer batch
data2 = list(data)

images, labels = data2[0]
images = images.numpy()
print("******* Tiempo total lectura batch: ", time.time() - tic)
# Out:
# ******* Tiempo total lectura batch:  0.017843008041381836

# %%
index_ct = 0
mensaje = f"CT Etiqueta: {labels.numpy()[index_ct]} "
print(mensaje)
img_print = images[index_ct]
label_print = labels.numpy()[index_ct]
fig = plt.figure(figsize=(10, 5))
columns = 10
rows = 7
depth_img = img_print.shape[2]

file_image_path = f'G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Imgs/TF_VF_Index{index_ct}_Rango{min_ventana}_{max_ventana}.png'
print(file_image_path)

plt.imshow(img_print)

# # ax enables access to manipulate each of subplots
# ax = []

# for i in range(1, depth_img+1):
#     img = np.squeeze(img_print[:, :, i-1])
#     #fig.add_subplot(rows, columns, i)
#     ax.append( fig.add_subplot(rows, columns, i))
#     ax[-1].set_title("depth:"+str(i))  # set title
#     plt.imshow(img, cmap='gray')
# plt.suptitle(mensaje)
# #plt.savefig(file_image_path)
# plt.show()
# Out:
# CT Etiqueta: 0
# G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Imgs/TF_VF_Index0_Rango-1000_0.png

# %% [markdown]
# # Modelo 1 - Data Augmentation Keras

# %%
def get_model(width=128, height=128):
    """Build a 3D convolutional neural network model."""

    inputs = keras.Input((width, height, 1))

    x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(inputs)
    x = layers.MaxPool2D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool2D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool2D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool2D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalMaxPooling2D()(x)
    x = layers.Dense(units=256, activation="relu")(x)
    x = layers.Dropout(0.2)(x)

    outputs = layers.Dense(units=1, activation="sigmoid")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="2dcnn")
    return model


# Build model.
model = get_model(width=128, height=128)
model.summary()
# Out:
# Model: "2dcnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  conv2d (Conv2D)             (None, 126, 126, 128)     1280
#
#  max_pooling2d (MaxPooling2  (None, 63, 63, 128)       0
#  D)
#
#  batch_normalization (Batch  (None, 63, 63, 128)       512
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 128)       147584
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 128)       0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 30, 30, 128)       512
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 256)       295168
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 256)       0
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 14, 14, 256)       1024
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 512)       1180160
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 512)         0
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 6, 6, 512)         2048
#  chNormalization)
#
#  global_max_pooling2d (Glob  (None, 512)               0
#  alMaxPooling2D)
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 1759873 (6.71 MB)
# Trainable params: 1757825 (6.71 MB)
# Non-trainable params: 2048 (8.00 KB)
# _________________________________________________________________

# %%
os.getcwd()
# Out:
# '/content'

# %%
if os.path.isfile(file_modelo):
  print(f"Ruta modelo existe!!!!!!!!!!!!!!!!!!!!!!!!!!!! {file_modelo}")
else:
  print(f"Se creará archivo: {file_modelo}")
# Out:
# Ruta modelo existe!!!!!!!!!!!!!!!!!!!!!!!!!!!! /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MEAN.h5

# %% [markdown]
# ## Compilar Modelo

# %%
tic = time.time()
# Compile model.
# initial_learning_rate = 0.0001
# lr_schedule = keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
# )

# reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min' ,factor=0.8,verbose=1,
#                               patience=5, min_lr=1e-6)

model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=initial_learning_rate),
    metrics=["acc", "BinaryIoU", "Recall"],
)

# Define callbacks.
checkpoint_cb = keras.callbacks.ModelCheckpoint(
    file_modelo,
    save_best_only=True, monitor = "val_loss", mode = "min", save_weights_only = True, verbose = 1,
)
early_stopping_cb = keras.callbacks.EarlyStopping(monitor="val_loss", mode = 'min', restore_best_weights = True, patience=30, verbose = 1)

# Train the model, doing validation at the end of each epoch
# epochs = 100
history = model.fit(
    train_dataset,
    validation_data=validation_dataset, #debería ser shuffle?
    epochs=epochs,
    verbose=1,
    callbacks=[checkpoint_cb, early_stopping_cb], #reduce_lr],
)
print("******* Tiempo total entrenamiento en minutos: ", (time.time() - tic)/60)
# Out:
# Epoch 1/150
# 148/148 [==============================] - ETA: 0s - loss: 1.0165 - acc: 0.5864 - binary_io_u: 0.3994 - recall: 0.4492
# Epoch 1: val_loss improved from inf to 0.67329, saving model to /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MEAN.h5
# 148/148 [==============================] - 9s 16ms/step - loss: 1.0165 - acc: 0.5864 - binary_io_u: 0.3994 - recall: 0.4492 - val_loss: 0.6733 - val_acc: 0.6000 - val_binary_io_u: 0.3000 - val_recall: 0.0000e+00
# Epoch 2/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.7801 - acc: 0.6069 - binary_io_u: 0.4211 - recall: 0.4786
# Epoch 2: val_loss did not improve from 0.67329
# 148/148 [==============================] - 1s 9ms/step - loss: 0.7710 - acc: 0.6136 - binary_io_u: 0.4272 - recall: 0.4831 - val_loss: 0.8679 - val_acc: 0.6000 - val_binary_io_u: 0.3000 - val_recall: 0.0000e+00
# Epoch 3/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.7206 - acc: 0.6434 - binary_io_u: 0.4604 - recall: 0.5259
# Epoch 3: val_loss did not improve from 0.67329
# 148/148 [==============================] - 1s 9ms/step - loss: 0.7496 - acc: 0.6305 - binary_io_u: 0.4482 - recall: 0.5339 - val_loss: 0.8913 - val_acc: 0.6000 - val_binary_io_u: 0.3000 - val_recall: 0.0000e+00
# Epoch 4/150
# 144/148 [============================>.] - ETA: 0s - loss: 0.7067 - acc: 0.6493 - binary_io_u: 0.4618 - recall: 0.5000
# Epoch 4: val_loss did not improve from 0.67329
# 148/148 [==============================] - 1s 9ms/step - loss: 0.7036 - acc: 0.6542 - binary_io_u: 0.4692 - recall: 0.5169 - val_loss: 0.6853 - val_acc: 0.6000 - val_binary_io_u: 0.3571 - val_recall: 0.1667
# Epoch 5/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.6792 - acc: 0.6690 - binary_io_u: 0.4814 - recall: 0.5088
# Epoch 5: val_loss improved from 0.67329 to 0.62178, saving model to /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MEAN.h5
# 148/148 [==============================] - 1s 10ms/step - loss: 0.6863 - acc: 0.6576 - binary_io_u: 0.4693 - recall: 0.4915 - val_loss: 0.6218 - val_acc: 0.6667 - val_binary_io_u: 0.4505 - val_recall: 0.3333
# Epoch 6/150
# 148/148 [==============================] - ETA: 0s - loss: 0.7186 - acc: 0.5966 - binary_io_u: 0.4028 - recall: 0.4068
# Epoch 6: val_loss did not improve from 0.62178
# 148/148 [==============================] - 1s 9ms/step - loss: 0.7186 - acc: 0.5966 - binary_io_u: 0.4028 - recall: 0.4068 - val_loss: 0.6333 - val_acc: 0.6000 - val_binary_io_u: 0.4032 - val_recall: 0.3889
# Epoch 7/150
# 148/148 [==============================] - ETA: 0s - loss: 0.6279 - acc: 0.6576 - binary_io_u: 0.4753 - recall: 0.5424
# Epoch 7: val_loss did not improve from 0.62178
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6279 - acc: 0.6576 - binary_io_u: 0.4753 - recall: 0.5424 - val_loss: 0.6600 - val_acc: 0.5778 - val_binary_io_u: 0.4039 - val_recall: 0.6111
# Epoch 8/150
# 144/148 [============================>.] - ETA: 0s - loss: 0.5921 - acc: 0.6667 - binary_io_u: 0.4828 - recall: 0.5304
# Epoch 8: val_loss did not improve from 0.62178
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6013 - acc: 0.6644 - binary_io_u: 0.4791 - recall: 0.5169 - val_loss: 0.7733 - val_acc: 0.6667 - val_binary_io_u: 0.4048 - val_recall: 0.1667
# Epoch 9/150
# 148/148 [==============================] - ETA: 0s - loss: 0.5645 - acc: 0.7017 - binary_io_u: 0.5268 - recall: 0.6017
# Epoch 9: val_loss improved from 0.62178 to 0.60992, saving model to /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MEAN.h5
# 148/148 [==============================] - 1s 10ms/step - loss: 0.5645 - acc: 0.7017 - binary_io_u: 0.5268 - recall: 0.6017 - val_loss: 0.6099 - val_acc: 0.7111 - val_binary_io_u: 0.5148 - val_recall: 0.4444
# Epoch 10/150
# 146/148 [============================>.] - ETA: 0s - loss: 0.5738 - acc: 0.6849 - binary_io_u: 0.4979 - recall: 0.5043
# Epoch 10: val_loss did not improve from 0.60992
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5793 - acc: 0.6780 - binary_io_u: 0.4903 - recall: 0.5000 - val_loss: 0.6574 - val_acc: 0.6222 - val_binary_io_u: 0.3879 - val_recall: 0.2222
# Epoch 11/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.5986 - acc: 0.7028 - binary_io_u: 0.5254 - recall: 0.5690
# Epoch 11: val_loss did not improve from 0.60992
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5995 - acc: 0.6983 - binary_io_u: 0.5196 - recall: 0.5678 - val_loss: 0.6644 - val_acc: 0.6222 - val_binary_io_u: 0.3879 - val_recall: 0.2222
# Epoch 12/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.5719 - acc: 0.6701 - binary_io_u: 0.4838 - recall: 0.5085
# Epoch 12: val_loss improved from 0.60992 to 0.60723, saving model to /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MEAN.h5
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5703 - acc: 0.6712 - binary_io_u: 0.4847 - recall: 0.5085 - val_loss: 0.6072 - val_acc: 0.6667 - val_binary_io_u: 0.4910 - val_recall: 0.6111
# Epoch 13/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.5970 - acc: 0.6429 - binary_io_u: 0.4575 - recall: 0.5085
# Epoch 13: val_loss did not improve from 0.60723
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5954 - acc: 0.6441 - binary_io_u: 0.4584 - recall: 0.5085 - val_loss: 0.6397 - val_acc: 0.6667 - val_binary_io_u: 0.4375 - val_recall: 0.2778
# Epoch 14/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.5678 - acc: 0.7133 - binary_io_u: 0.5404 - recall: 0.6034
# Epoch 14: val_loss did not improve from 0.60723
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5656 - acc: 0.7153 - binary_io_u: 0.5424 - recall: 0.6102 - val_loss: 0.6365 - val_acc: 0.6667 - val_binary_io_u: 0.4505 - val_recall: 0.3333
# Epoch 15/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.5767 - acc: 0.6783 - binary_io_u: 0.4904 - recall: 0.5000
# Epoch 15: val_loss did not improve from 0.60723
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5715 - acc: 0.6814 - binary_io_u: 0.4937 - recall: 0.5000 - val_loss: 0.6306 - val_acc: 0.6667 - val_binary_io_u: 0.4617 - val_recall: 0.3889
# Epoch 16/150
# 146/148 [============================>.] - ETA: 0s - loss: 0.5588 - acc: 0.7158 - binary_io_u: 0.5436 - recall: 0.6154
# Epoch 16: val_loss did not improve from 0.60723
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5597 - acc: 0.7153 - binary_io_u: 0.5433 - recall: 0.6186 - val_loss: 0.6376 - val_acc: 0.5556 - val_binary_io_u: 0.3665 - val_recall: 0.3889
# Epoch 17/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.5479 - acc: 0.7103 - binary_io_u: 0.5345 - recall: 0.5913
# Epoch 17: val_loss did not improve from 0.60723
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5467 - acc: 0.7119 - binary_io_u: 0.5369 - recall: 0.5932 - val_loss: 0.6083 - val_acc: 0.6667 - val_binary_io_u: 0.4617 - val_recall: 0.3889
# Epoch 18/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.5317 - acc: 0.7414 - binary_io_u: 0.5788 - recall: 0.6695
# Epoch 18: val_loss did not improve from 0.60723
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5268 - acc: 0.7458 - binary_io_u: 0.5829 - recall: 0.6695 - val_loss: 0.6641 - val_acc: 0.6667 - val_binary_io_u: 0.4375 - val_recall: 0.2778
# Epoch 19/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.5285 - acc: 0.7343 - binary_io_u: 0.5618 - recall: 0.6018
# Epoch 19: val_loss did not improve from 0.60723
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5354 - acc: 0.7288 - binary_io_u: 0.5546 - recall: 0.5847 - val_loss: 0.6470 - val_acc: 0.6889 - val_binary_io_u: 0.5083 - val_recall: 0.5556
# Epoch 20/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.5549 - acc: 0.7218 - binary_io_u: 0.5494 - recall: 0.6161
# Epoch 20: val_loss improved from 0.60723 to 0.59815, saving model to /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MEAN.h5
# 148/148 [==============================] - 2s 14ms/step - loss: 0.5584 - acc: 0.7186 - binary_io_u: 0.5462 - recall: 0.6102 - val_loss: 0.5981 - val_acc: 0.7111 - val_binary_io_u: 0.5380 - val_recall: 0.6111
# Epoch 21/150
# 146/148 [============================>.] - ETA: 0s - loss: 0.5815 - acc: 0.7226 - binary_io_u: 0.5512 - recall: 0.6154
# Epoch 21: val_loss did not improve from 0.59815
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5790 - acc: 0.7254 - binary_io_u: 0.5546 - recall: 0.6186 - val_loss: 0.6220 - val_acc: 0.6222 - val_binary_io_u: 0.4423 - val_recall: 0.5556
# Epoch 22/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.5296 - acc: 0.7345 - binary_io_u: 0.5659 - recall: 0.6239
# Epoch 22: val_loss did not improve from 0.59815
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5276 - acc: 0.7356 - binary_io_u: 0.5660 - recall: 0.6186 - val_loss: 0.6249 - val_acc: 0.6889 - val_binary_io_u: 0.4705 - val_recall: 0.3333
# Epoch 23/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.5447 - acc: 0.7273 - binary_io_u: 0.5569 - recall: 0.6174
# Epoch 23: val_loss did not improve from 0.59815
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5438 - acc: 0.7288 - binary_io_u: 0.5575 - recall: 0.6102 - val_loss: 0.6527 - val_acc: 0.6889 - val_binary_io_u: 0.4705 - val_recall: 0.3333
# Epoch 24/150
# 144/148 [============================>.] - ETA: 0s - loss: 0.5410 - acc: 0.7257 - binary_io_u: 0.5507 - recall: 0.5826
# Epoch 24: val_loss did not improve from 0.59815
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5360 - acc: 0.7254 - binary_io_u: 0.5498 - recall: 0.5763 - val_loss: 0.6458 - val_acc: 0.6222 - val_binary_io_u: 0.4011 - val_recall: 0.2778
# Epoch 25/150
# 146/148 [============================>.] - ETA: 0s - loss: 0.5201 - acc: 0.7123 - binary_io_u: 0.5352 - recall: 0.5776
# Epoch 25: val_loss did not improve from 0.59815
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5289 - acc: 0.7085 - binary_io_u: 0.5304 - recall: 0.5678 - val_loss: 0.6344 - val_acc: 0.6444 - val_binary_io_u: 0.4049 - val_recall: 0.2222
# Epoch 26/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.5030 - acc: 0.7622 - binary_io_u: 0.5992 - recall: 0.6348
# Epoch 26: val_loss did not improve from 0.59815
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5088 - acc: 0.7593 - binary_io_u: 0.5964 - recall: 0.6441 - val_loss: 0.6353 - val_acc: 0.6222 - val_binary_io_u: 0.4493 - val_recall: 0.6667
# Epoch 27/150
# 148/148 [==============================] - ETA: 0s - loss: 0.5233 - acc: 0.7254 - binary_io_u: 0.5527 - recall: 0.6017
# Epoch 27: val_loss improved from 0.59815 to 0.58113, saving model to /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MEAN.h5
# 148/148 [==============================] - 2s 12ms/step - loss: 0.5233 - acc: 0.7254 - binary_io_u: 0.5527 - recall: 0.6017 - val_loss: 0.5811 - val_acc: 0.6889 - val_binary_io_u: 0.5012 - val_recall: 0.5000
# Epoch 28/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.5137 - acc: 0.7551 - binary_io_u: 0.5925 - recall: 0.6525
# Epoch 28: val_loss did not improve from 0.58113
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5150 - acc: 0.7525 - binary_io_u: 0.5892 - recall: 0.6525 - val_loss: 0.5941 - val_acc: 0.7556 - val_binary_io_u: 0.5722 - val_recall: 0.5000
# Epoch 29/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.5363 - acc: 0.7207 - binary_io_u: 0.5495 - recall: 0.6207
# Epoch 29: val_loss improved from 0.58113 to 0.56761, saving model to /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MEAN.h5
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5354 - acc: 0.7220 - binary_io_u: 0.5508 - recall: 0.6186 - val_loss: 0.5676 - val_acc: 0.6667 - val_binary_io_u: 0.4712 - val_recall: 0.4444
# Epoch 30/150
# 144/148 [============================>.] - ETA: 0s - loss: 0.4567 - acc: 0.7847 - binary_io_u: 0.6350 - recall: 0.7217
# Epoch 30: val_loss improved from 0.56761 to 0.55930, saving model to /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MEAN.h5
# 148/148 [==============================] - 1s 9ms/step - loss: 0.4553 - acc: 0.7864 - binary_io_u: 0.6372 - recall: 0.7203 - val_loss: 0.5593 - val_acc: 0.7111 - val_binary_io_u: 0.5240 - val_recall: 0.5000
# Epoch 31/150
# 148/148 [==============================] - ETA: 0s - loss: 0.4717 - acc: 0.7932 - binary_io_u: 0.6459 - recall: 0.7203
# Epoch 31: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.4717 - acc: 0.7932 - binary_io_u: 0.6459 - recall: 0.7203 - val_loss: 0.5847 - val_acc: 0.6000 - val_binary_io_u: 0.4249 - val_recall: 0.6111
# Epoch 32/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.4594 - acc: 0.7657 - binary_io_u: 0.6025 - recall: 0.6372
# Epoch 32: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.4637 - acc: 0.7627 - binary_io_u: 0.5995 - recall: 0.6356 - val_loss: 0.5932 - val_acc: 0.7111 - val_binary_io_u: 0.5148 - val_recall: 0.4444
# Epoch 33/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.4430 - acc: 0.8027 - binary_io_u: 0.6592 - recall: 0.7288
# Epoch 33: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.4484 - acc: 0.8000 - binary_io_u: 0.6554 - recall: 0.7288 - val_loss: 0.6269 - val_acc: 0.6222 - val_binary_io_u: 0.4011 - val_recall: 0.2778
# Epoch 34/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.4946 - acc: 0.7448 - binary_io_u: 0.5759 - recall: 0.6174
# Epoch 34: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.4931 - acc: 0.7458 - binary_io_u: 0.5786 - recall: 0.6271 - val_loss: 0.6498 - val_acc: 0.6444 - val_binary_io_u: 0.4416 - val_recall: 0.3889
# Epoch 35/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.4575 - acc: 0.7621 - binary_io_u: 0.6042 - recall: 0.6838
# Epoch 35: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.4570 - acc: 0.7627 - binary_io_u: 0.6047 - recall: 0.6864 - val_loss: 0.6214 - val_acc: 0.6889 - val_binary_io_u: 0.5141 - val_recall: 0.6111
# Epoch 36/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.4129 - acc: 0.8007 - binary_io_u: 0.6589 - recall: 0.7436
# Epoch 36: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.4134 - acc: 0.8000 - binary_io_u: 0.6561 - recall: 0.7373 - val_loss: 0.6639 - val_acc: 0.6222 - val_binary_io_u: 0.4303 - val_recall: 0.4444
# Epoch 37/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.4620 - acc: 0.7727 - binary_io_u: 0.6156 - recall: 0.6696
# Epoch 37: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.4579 - acc: 0.7763 - binary_io_u: 0.6205 - recall: 0.6780 - val_loss: 0.6372 - val_acc: 0.6222 - val_binary_io_u: 0.4464 - val_recall: 0.6111
# Epoch 38/150
# 144/148 [============================>.] - ETA: 0s - loss: 0.4919 - acc: 0.7847 - binary_io_u: 0.6335 - recall: 0.6983
# Epoch 38: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5051 - acc: 0.7797 - binary_io_u: 0.6271 - recall: 0.7034 - val_loss: 0.6074 - val_acc: 0.7111 - val_binary_io_u: 0.5317 - val_recall: 0.5556
# Epoch 39/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.4371 - acc: 0.7746 - binary_io_u: 0.6185 - recall: 0.6754
# Epoch 39: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.4371 - acc: 0.7729 - binary_io_u: 0.6163 - recall: 0.6780 - val_loss: 0.6350 - val_acc: 0.7111 - val_binary_io_u: 0.5148 - val_recall: 0.4444
# Epoch 40/150
# 146/148 [============================>.] - ETA: 0s - loss: 0.4255 - acc: 0.8082 - binary_io_u: 0.6646 - recall: 0.7034
# Epoch 40: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.4272 - acc: 0.8068 - binary_io_u: 0.6620 - recall: 0.7034 - val_loss: 0.6612 - val_acc: 0.6000 - val_binary_io_u: 0.4249 - val_recall: 0.6111
# Epoch 41/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.4423 - acc: 0.7759 - binary_io_u: 0.6203 - recall: 0.6752
# Epoch 41: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.4419 - acc: 0.7763 - binary_io_u: 0.6205 - recall: 0.6780 - val_loss: 0.7279 - val_acc: 0.5778 - val_binary_io_u: 0.4010 - val_recall: 0.5556
# Epoch 42/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.3829 - acc: 0.8239 - binary_io_u: 0.6919 - recall: 0.7739
# Epoch 42: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.3819 - acc: 0.8237 - binary_io_u: 0.6901 - recall: 0.7627 - val_loss: 0.7309 - val_acc: 0.6000 - val_binary_io_u: 0.3837 - val_recall: 0.2778
# Epoch 43/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.3712 - acc: 0.8252 - binary_io_u: 0.6863 - recall: 0.7143
# Epoch 43: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.3747 - acc: 0.8237 - binary_io_u: 0.6864 - recall: 0.7203 - val_loss: 0.7733 - val_acc: 0.5556 - val_binary_io_u: 0.3833 - val_recall: 0.7778
# Epoch 44/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.4068 - acc: 0.8172 - binary_io_u: 0.6771 - recall: 0.7155
# Epoch 44: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.4044 - acc: 0.8203 - binary_io_u: 0.6818 - recall: 0.7203 - val_loss: 0.6220 - val_acc: 0.6444 - val_binary_io_u: 0.4741 - val_recall: 0.7222
# Epoch 45/150
# 146/148 [============================>.] - ETA: 0s - loss: 0.3534 - acc: 0.8699 - binary_io_u: 0.7595 - recall: 0.8087
# Epoch 45: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 10ms/step - loss: 0.3739 - acc: 0.8610 - binary_io_u: 0.7455 - recall: 0.7881 - val_loss: 0.6856 - val_acc: 0.6444 - val_binary_io_u: 0.4578 - val_recall: 0.5000
# Epoch 46/150
# 148/148 [==============================] - ETA: 0s - loss: 0.3837 - acc: 0.8169 - binary_io_u: 0.6827 - recall: 0.7881
# Epoch 46: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.3837 - acc: 0.8169 - binary_io_u: 0.6827 - recall: 0.7881 - val_loss: 0.7170 - val_acc: 0.5556 - val_binary_io_u: 0.3500 - val_recall: 0.2778
# Epoch 47/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.3631 - acc: 0.8345 - binary_io_u: 0.7047 - recall: 0.7521
# Epoch 47: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.3617 - acc: 0.8373 - binary_io_u: 0.7083 - recall: 0.7542 - val_loss: 0.6549 - val_acc: 0.6889 - val_binary_io_u: 0.5012 - val_recall: 0.5000
# Epoch 48/150
# 148/148 [==============================] - ETA: 0s - loss: 0.3469 - acc: 0.8475 - binary_io_u: 0.7236 - recall: 0.7627
# Epoch 48: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.3469 - acc: 0.8475 - binary_io_u: 0.7236 - recall: 0.7627 - val_loss: 0.7670 - val_acc: 0.6222 - val_binary_io_u: 0.4493 - val_recall: 0.8889
# Epoch 49/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.3365 - acc: 0.8605 - binary_io_u: 0.7468 - recall: 0.8205
# Epoch 49: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.3371 - acc: 0.8610 - binary_io_u: 0.7479 - recall: 0.8220 - val_loss: 0.6974 - val_acc: 0.5556 - val_binary_io_u: 0.3810 - val_recall: 0.5556
# Epoch 50/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.3341 - acc: 0.8531 - binary_io_u: 0.7356 - recall: 0.8017
# Epoch 50: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.3288 - acc: 0.8576 - binary_io_u: 0.7417 - recall: 0.8051 - val_loss: 0.6995 - val_acc: 0.6444 - val_binary_io_u: 0.4505 - val_recall: 0.4444
# Epoch 51/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.3123 - acc: 0.8803 - binary_io_u: 0.7793 - recall: 0.8509
# Epoch 51: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.3170 - acc: 0.8746 - binary_io_u: 0.7701 - recall: 0.8475 - val_loss: 0.6526 - val_acc: 0.6222 - val_binary_io_u: 0.4464 - val_recall: 0.6111
# Epoch 52/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.3230 - acc: 0.8828 - binary_io_u: 0.7810 - recall: 0.8261
# Epoch 52: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.3237 - acc: 0.8814 - binary_io_u: 0.7796 - recall: 0.8305 - val_loss: 0.7369 - val_acc: 0.6444 - val_binary_io_u: 0.4505 - val_recall: 0.4444
# Epoch 53/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.3098 - acc: 0.8673 - binary_io_u: 0.7571 - recall: 0.8136
# Epoch 53: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.3091 - acc: 0.8678 - binary_io_u: 0.7576 - recall: 0.8136 - val_loss: 0.7210 - val_acc: 0.6222 - val_binary_io_u: 0.4303 - val_recall: 0.4444
# Epoch 54/150
# 146/148 [============================>.] - ETA: 0s - loss: 0.2726 - acc: 0.9041 - binary_io_u: 0.8182 - recall: 0.8559
# Epoch 54: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.2736 - acc: 0.9051 - binary_io_u: 0.8193 - recall: 0.8559 - val_loss: 0.6729 - val_acc: 0.6444 - val_binary_io_u: 0.4637 - val_recall: 0.5556
# Epoch 55/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.3675 - acc: 0.8503 - binary_io_u: 0.7306 - recall: 0.7966
# Epoch 55: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.3663 - acc: 0.8508 - binary_io_u: 0.7311 - recall: 0.7966 - val_loss: 0.6901 - val_acc: 0.6889 - val_binary_io_u: 0.5141 - val_recall: 0.6111
# Epoch 56/150
# 144/148 [============================>.] - ETA: 0s - loss: 0.3680 - acc: 0.8542 - binary_io_u: 0.7348 - recall: 0.7895
# Epoch 56: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.3645 - acc: 0.8576 - binary_io_u: 0.7411 - recall: 0.7966 - val_loss: 0.6683 - val_acc: 0.6889 - val_binary_io_u: 0.5012 - val_recall: 0.5000
# Epoch 57/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.3030 - acc: 0.8707 - binary_io_u: 0.7617 - recall: 0.8120
# Epoch 57: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.3041 - acc: 0.8712 - binary_io_u: 0.7627 - recall: 0.8136 - val_loss: 0.7684 - val_acc: 0.7333 - val_binary_io_u: 0.5558 - val_recall: 0.5556
# Epoch 58/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.2435 - acc: 0.9126 - binary_io_u: 0.8328 - recall: 0.8696
# Epoch 58: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.2507 - acc: 0.9085 - binary_io_u: 0.8249 - recall: 0.8559 - val_loss: 0.9905 - val_acc: 0.6667 - val_binary_io_u: 0.4375 - val_recall: 0.2778
# Epoch 59/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.2729 - acc: 0.8768 - binary_io_u: 0.7728 - recall: 0.8407
# Epoch 59: val_loss did not improve from 0.55930
# 148/148 [==============================] - 1s 9ms/step - loss: 0.2741 - acc: 0.8780 - binary_io_u: 0.7753 - recall: 0.8475 - val_loss: 0.8246 - val_acc: 0.7111 - val_binary_io_u: 0.5240 - val_recall: 0.5000
# Epoch 60/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.2152 - acc: 0.9320 - binary_io_u: 0.8681 - recall: 0.9153
# Epoch 60: val_loss did not improve from 0.55930
# Restoring model weights from the end of the best epoch: 30.
# 148/148 [==============================] - 1s 9ms/step - loss: 0.2185 - acc: 0.9288 - binary_io_u: 0.8625 - recall: 0.9153 - val_loss: 0.7316 - val_acc: 0.6667 - val_binary_io_u: 0.4910 - val_recall: 0.6111
# Epoch 60: early stopping
# ******* Tiempo total entrenamiento en minutos:  1.510446051756541

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, metric in enumerate(["acc", "loss"]):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 3))
ax = ax.ravel()

for i, metric in enumerate(["acc","binary_io_u", "recall"]):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'acc', 'binary_io_u', 'recall', 'val_loss', 'val_acc', 'val_binary_io_u', 'val_recall'])

# %%
file_history
# Out:
# '/content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/History_Modelo_Keras_Arch_W4_V1_Optimizado_2D_MEAN'

# %%
with open(file_history, 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# Para leer https://stackoverflow.com/questions/41061457/keras-how-to-save-the-training-history-attribute-of-the-history-object

# %%
model.evaluate(validation_dataset, verbose=2)
# Out:
# 23/23 - 0s - loss: 0.5593 - acc: 0.7111 - binary_io_u: 0.5240 - recall: 0.5000 - 89ms/epoch - 4ms/step
# [0.5592988133430481, 0.7111111283302307, 0.5239899158477783, 0.5]

# %%
# file_modelo2 = '/content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_3D_W4_V1.h5'
print(f"Leyendo pesos del modelo: {file_modelo}")
model.load_weights(file_modelo)
# Out:
# Leyendo pesos del modelo: /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MEAN.h5

# %%
model.evaluate(validation_dataset, verbose=2)
# Out:
# 23/23 - 0s - loss: 0.5593 - acc: 0.7111 - binary_io_u: 0.5240 - recall: 0.5000 - 123ms/epoch - 5ms/step
# [0.5592988133430481, 0.7111111283302307, 0.5239899158477783, 0.5]

# %%
y_valid_estimado = model.predict(validation_dataset)
# Out:
# 23/23 [==============================] - 0s 3ms/step

# %%
y_valid_estimado
# Out:
# array([[0.4475484 ],
#        [0.15097463],
#        [0.02916194],
#        [0.18602768],
#        [0.3977959 ],
#        [0.4492068 ],
#        [0.26500583],
#        [0.17702036],
#        [0.5455892 ],
#        [0.08973125],
#        [0.13461041],
#        [0.4659436 ],
#        [0.7422874 ],
#        [0.44069204],
#        [0.31945583],
#        [0.27308092],
#        [0.08529345],
#        [0.27493748],
#        [0.5447409 ],
#        [0.13142297],
#        [0.39607668],
#        [0.44670868],
#        [0.14000596],
#        [0.10399088],
#        [0.52829504],
#        [0.07618389],
#        [0.09146012],
#        [0.31743035],
#        [0.86445415],
#        [0.21996112],
#        [0.7648166 ],
#        [0.46348256],
#        [0.36580494],
#        [0.10061282],
#        [0.5259815 ],
#        [0.5561791 ],
#        [0.6253132 ],
#        [0.5174812 ],
#        [0.34545508],
#        [0.7933862 ],
#        [0.61319596],
#        [0.4178948 ],
#        [0.3466589 ],
#        [0.6657298 ],
#        [0.3583791 ]], dtype=float32)

# %% [markdown]
# ## Calculando métricas del modelo

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(
    cm, classes,
    normalize = False,
    title = 'Matriz de Confusión',
    cmap = plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalizacion can be applied by setting 'normalize = True'
    """

    plt.imshow(cm,interpolation = 'nearest', cmap= cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks,classes,rotation = 45)
    plt.yticks(tick_marks,classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix without normalization')

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment = "center",
                 color = "white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel("Etiqueta Verdadera")
    plt.xlabel("Etiqueta Predicha")

def calcular_metricas(nombre_modelo, tipo_set, etiquetas_reales, etiquetas_estimadas, etiquetas_estimadas_prob):

    print("Tipo:",tipo_set)

    # accuracy: (tp + tn) / (p + n)
    accuracy = accuracy_score(etiquetas_reales, etiquetas_estimadas)
    print('Accuracy: %f' % accuracy)
    # precision tp / (tp + fp)
    precision = precision_score(etiquetas_reales, etiquetas_estimadas)
    print('Precision: %f' % precision)
    # recall: tp / (tp + fn)
    recall = recall_score(etiquetas_reales, etiquetas_estimadas)
    print('Recall: %f' % recall)
    # f1: 2 tp / (2 tp + fp + fn)
    f1 = f1_score(etiquetas_reales, etiquetas_estimadas)
    print('F1 score: %f' % f1)

    # kappa
    kappa = cohen_kappa_score(etiquetas_reales, etiquetas_estimadas)
    print('Cohens kappa: %f' % kappa)
    # ROC AUC
    auc = roc_auc_score(etiquetas_reales, etiquetas_estimadas_prob)
    print('ROC AUC: %f' % auc)
    # IoU
    iou = tf.keras.metrics.IoU(num_classes=2, target_class_ids=[1])
    iou.update_state(etiquetas_reales, etiquetas_estimadas, sample_weight=None)
    iou = iou.result().numpy()
    # FBeta-Score
    beta = 2
    b2 = beta ** 2
    f_beta_score = (1 + b2) * (precision * recall) / (precision * b2 + recall)

    # confusion matrix
    matrix = confusion_matrix(etiquetas_reales, etiquetas_estimadas)
    print(matrix)

    # TP; FP; TN; FN
    TP = matrix[1][1]
    FP = matrix[0][1]
    TN = matrix[0][0]
    FN = matrix[1][0]


    df_modelo = pd.DataFrame(
        {"nombre_modelo" : [nombre_modelo],
        "tipo_set" : [tipo_set],
        "accuracy" : [accuracy],
        "precision" : [precision],
        "recall": [recall],
        "f1": [f1],
        "Cohens kappa": [kappa],
        "ROC AUC": [auc],
        "IoU": [iou],
        "FBetaScore": [f_beta_score],
        'TP':[TP],
        'FP':[FP],
        'TN':[TN],
        'FN':[FN],
        }
    )

    return df_modelo, matrix

# %%
if reading_cts_tf == False:
  print("Dataset seguimiento modelo con datasets_iteration2")
  p_train_dataset = datasets_iteration2(x_train, train_df)
else:
  print("Dataset seguimiento modelo con lectura repetitiva de los CTs por batches")
  p_train_dataset = datasets_iteration(train_df) # Para poder sacar el cálculo y las etiquetas

# p_test_dataset = datasets_iteration(test_df)
# p_validation_dataset = datasets_iteration(valid_df)

prueba_shuffle = datasets_iteration(valid_df.iloc[[25,26,27]], True)
prueba_shuffle

prueba_shuffle2 = datasets_iteration(valid_df.iloc[[25,26,27]])
prueba_shuffle2
# Out:
# Dataset seguimiento modelo con datasets_iteration2
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %%
etiquetas_shuffle = np.concatenate([y for x, y in prueba_shuffle], axis=0)
etiquetas_shuffle
# Out:
# array([0, 1, 0])

# %%
etiquetas_shuffle = np.concatenate([y for x, y in prueba_shuffle2], axis=0)
etiquetas_shuffle
# Out:
# array([0, 0, 1])

# %%
y_train = train_df['Label']
y_test = test_df['Label']
y_valid = valid_df['Label']

# %%
# Ajustando probabilidades para los datos. Se apunta a la probabilidad de 1 (positiva).
print("Train")
yhat_probs_train = model.predict(p_train_dataset, verbose=0)
print("Test")
yhat_probs_test = model.predict(test_dataset, verbose=0)
print("Valid")
yhat_probs_valid = model.predict(validation_dataset, verbose=0)


# Calculamos las clases
print("Clases")
yhat_classes_train = ((yhat_probs_train > 0.5)+0).ravel()
yhat_classes_test = ((yhat_probs_test > 0.5)+0).ravel()
yhat_classes_valid = ((yhat_probs_valid > 0.5)+0).ravel()

print("Shapes")
print("Shape train", yhat_classes_train.shape)
print("Shape test", yhat_classes_test.shape)
print("Shape valid", yhat_classes_valid.shape)
# Out:
# Train
# Test
# Valid
# Clases
# Shapes
# Shape train (295,)
# Shape test (84,)
# Shape valid (45,)

# %%
# Lo dejamos como 1d array
# yhat_probs_train = yhat_probs_train[:, 0]
# yhat_probs_test = yhat_probs_test[:, 0]
# yhat_probs_valid = yhat_probs_valid[:, 0]

#yhat_classes_train = yhat_classes_train[:, 0]
#yhat_classes_test = yhat_classes_test[:, 0]
#yhat_classes_valid = yhat_classes_valid[:, 0]

# %% [markdown]
# ### Métricas

# %%
metricas_train, cm_train = calcular_metricas(nombre_modelo = version_modelo,
                    tipo_set="Training",
                    etiquetas_reales=y_train,
                    etiquetas_estimadas=yhat_classes_train,
                    etiquetas_estimadas_prob=yhat_probs_train)

metricas_valid, cm_valid = calcular_metricas(nombre_modelo = version_modelo,
                    tipo_set="Validacion",
                    etiquetas_reales=y_valid,
                    etiquetas_estimadas=yhat_classes_valid,
                    etiquetas_estimadas_prob=yhat_probs_valid)

metricas_test, cm_test = calcular_metricas(nombre_modelo = version_modelo,
                    tipo_set="Test",
                    etiquetas_reales=y_test,
                    etiquetas_estimadas=yhat_classes_test,
                    etiquetas_estimadas_prob=yhat_probs_test)


resumen_modelo = pd.concat([metricas_train,metricas_valid,metricas_test]).reset_index(drop = True)
resumen_modelo
# Out:
# Tipo: Training
# Accuracy: 0.803390
# Precision: 0.800000
# Recall: 0.677966
# F1 score: 0.733945
# Cohens kappa: 0.579710
# ROC AUC: 0.881595
# [[157  20]
#  [ 38  80]]
# Tipo: Validacion
# Accuracy: 0.711111
# Precision: 0.692308
# Recall: 0.500000
# F1 score: 0.580645
# Cohens kappa: 0.368932
# ROC AUC: 0.755144
# [[23  4]
#  [ 9  9]]
# Tipo: Test
# Accuracy: 0.654762
# Precision: 0.631579
# Recall: 0.352941
# F1 score: 0.452830
# Cohens kappa: 0.229114
# ROC AUC: 0.790588
# [[43  7]
#  [22 12]]
#                          nombre_modelo    tipo_set  accuracy  precision  \
# 0  Keras_Arch_W4_V1_Optimizado_2D_MEAN    Training     0.803      0.800
# 1  Keras_Arch_W4_V1_Optimizado_2D_MEAN  Validacion     0.711      0.692
# 2  Keras_Arch_W4_V1_Optimizado_2D_MEAN        Test     0.655      0.632
#
#    recall    f1  Cohens kappa  ROC AUC   IoU  FBetaScore  TP  FP   TN  FN
# 0   0.678 0.734         0.580    0.882 0.580       0.699  80  20  157  38
# 1   0.500 0.581         0.369    0.755 0.409       0.529   9   4   23   9
# 2   0.353 0.453         0.229    0.791 0.293       0.387  12   7   43  22

# %%
r'{}{}'.format(ruta_modelo,f"{version_modelo}.xlsx")
# Out:
# '/content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Keras_Arch_W4_V1_Optimizado_2D_MEAN.xlsx'

# %%
resumen_modelo.to_excel(r'{}{}'.format(ruta_modelo,f"{version_modelo}.xlsx"), index = False)

# %%
etiquetas_vf = ['No Signos Neumonia','Signos Neumonia']

# %%
plot_confusion_matrix(cm = cm_train, classes = etiquetas_vf,title = "Confusion Matrix Neumonía")
# Out:
# Confusion matrix without normalization

# %%
plot_confusion_matrix(cm = cm_valid, classes = etiquetas_vf,title = "Confusion Matrix Neumonía")
# Out:
# Confusion matrix without normalization

# %%
plot_confusion_matrix(cm = cm_test, classes = etiquetas_vf,title = "Confusion Matrix Neumonía")
# Out:
# Confusion matrix without normalization

# %%
valid_df['Label'].value_counts()
# Out:
# Label
# 0    27
# 1    18
# Name: count, dtype: int64
