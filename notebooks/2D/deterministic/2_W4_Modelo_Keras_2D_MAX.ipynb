# %% [markdown]
# # Prueba Modelo con Data Augmentacion:
# - Proceso de lectura a través de TF.
# - Adicional se vuelve a tomar la parte de la lectura de los CTs una sola vez.

# %% [markdown]
# # Modelo.
# - Limitación pixeles de -1000 a 0
# - Prueba ventana parénquima pulmonar desde W3. Para ver si hay algo raro en el script.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install volumentations-3D
# !pip install keras-tuner --upgrade
# !pip install keras_applications
# !pip install tensorflow==2.11.0
# !pip install keras==2.11.0
# Out:
# Collecting volumentations-3D
#   Downloading volumentations_3D-1.0.4-py3-none-any.whl (31 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from volumentations-3D) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from volumentations-3D) (1.11.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from volumentations-3D) (4.8.0.76)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from volumentations-3D) (1.25.2)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->volumentations-3D) (3.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->volumentations-3D) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->volumentations-3D) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->volumentations-3D) (2024.4.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->volumentations-3D) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->volumentations-3D) (24.0)
# Installing collected packages: volumentations-3D
# Successfully installed volumentations-3D-1.0.4

# %%
# Tratamiento datos
import pandas as pd
import numpy as np
from collections import Counter
import time

# Organizar rutas imágenes
import os
import random

# Lectura tomografías.
import nibabel as nib # Lectura
from scipy import ndimage # Tratamiento

# Modelado
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Data Augmentation
from volumentations import *

# Visualización CTs
import matplotlib.pyplot as plt
import re

import itertools
from functools import partial

pd.set_option('display.max_columns', 500)
pd.set_option('display.float_format', lambda x: f'{x:.3f}')
#pd.set_option('display.float_format', lambda x: f'{x:,.3f}') #add a comma separator between the thousands.
pd.set_option('display.max_colwidth',1000)



np.set_printoptions(threshold=1000, linewidth = 300, edgeitems = 5)
np.set_printoptions(suppress=True)


import pickle

# %% [markdown]
# # Parámetros

# %%
ambiente = 'GOOGLE' # 'GOOGLE' o 'LOCAL'
reduccion = "MAX" # SUM o MEAN
reading_cts_tf = False
version_modelo = "Keras_Arch_W4_V1_Optimizado_2D_MAX" # CAMBIAR!!!!!!!!!!!!!!!!!!!!!!!!!!

# Ventana Parénquima Pulmonar
min_ventana = -1000
max_ventana = 0

# Rutas Datasets
ruta_dfs_google = r'/content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Path_Sets/'
ruta_dfs_local = r'G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Path_Sets/'

ruta_modelo_google = r'/content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/'
ruta_modelo_local = r'G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Modelos/'

# Rutas
if ambiente == 'GOOGLE':
    print("Rutas DFs")
    ruta_dfs = ruta_dfs_google

    print("El modelo se guardará en Modelos_Colab")
    ruta_modelo = ruta_modelo_google
    file_modelo = r'{}Modelo_{}.h5'.format(ruta_modelo_google,version_modelo)
    file_history = r'{}History_Modelo_{}'.format(ruta_modelo_google,version_modelo)

else:
    print("Rutas DFs")
    ruta_dfs = ruta_dfs_local

    print("El modelo se guardará en Modelos")
    ruta_modelo = ruta_modelo_local
    file_modelo = r'{}Modelo_{}.h5'.format(ruta_modelo_local,version_modelo)
    file_history = r'{}History_Modelo_{}'.format(ruta_modelo_local,version_modelo)

# Validando rutas
if os.path.exists(ruta_modelo):
    print("Existe ruta guardado modelo.")
    print(f"El modelo se guardará en: {file_modelo}")
else:
    print("Creando ruta para modelos!!!!!!! ")
    os.makedirs(ruta_modelo)

print(ruta_modelo)

# Parámetros Redes:
BATCH_SIZE=2
RANDOM = 9411
initial_learning_rate = 0.0001
epochs = 150
# Out:
# Rutas DFs
# El modelo se guardará en Modelos_Colab
# Existe ruta guardado modelo.
# El modelo se guardará en: /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MAX.h5
# /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/

# %% [markdown]
# # Lectura Imágenes

# %% [markdown]
# ## Rutas

# %%
if ambiente == 'GOOGLE':
    print("Leyendo rutas de google")
    train_df = pd.read_csv(ruta_dfs + 'train_df.csv')
    test_df = pd.read_csv(ruta_dfs + 'test_df.csv')
    valid_df = pd.read_csv(ruta_dfs + 'valid_df.csv')

    train_df['path'] = train_df['File_Path_Google']
    test_df['path'] = test_df['File_Path_Google']
    valid_df['path'] = valid_df['File_Path_Google']

else:
    print("Leyendo rutas del local")
    train_df = pd.read_csv(ruta_dfs + 'train_df.csv')
    test_df = pd.read_csv(ruta_dfs + 'test_df.csv')
    valid_df = pd.read_csv(ruta_dfs + 'valid_df.csv')

    train_df['path'] = train_df['File_Path']
    test_df['path'] = test_df['File_Path']
    valid_df['path'] = valid_df['File_Path']
# Out:
# Leyendo rutas de google

# %%
# train_df = pd.DataFrame({'path' : ['/content/data/study_0001.nii.gz',
#                                    '/content/data/study_0002.nii.gz',
#                                    '/content/data/study_0003.nii.gz',
#                                    '/content/data/study_0004.nii.gz']})
# train_df['Label'] = 0

# valid_df = pd.DataFrame({'path' : ['/content/data/study_0003.nii.gz',
#                                    '/content/data/study_0004.nii.gz',
#                                    '/content/data/study_0005.nii.gz']})
# valid_df['Label'] = 0

# test_df = valid_df.copy()


# train_df

# %%
valid_df.head()
# Out:
#                                                                   File_Path  \
# 0  G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0026.nii.gz
# 1  G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0031.nii.gz
# 2  G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0180.nii.gz
# 3  G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0075.nii.gz
# 4  G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0139.nii.gz
#
#                                                                       File_Path_Google  \
# 0  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0026.nii.gz
# 1  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0031.nii.gz
# 2  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0180.nii.gz
# 3  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0075.nii.gz
# 4  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0139.nii.gz
#
#    Label  \
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#
#                                                                                   path
# 0  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0026.nii.gz
# 1  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0031.nii.gz
# 2  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0180.nii.gz
# 3  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0075.nii.gz
# 4  /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Data/Real/CT-0/study_0139.nii.gz

# %% [markdown]
# ## Lectura:

# %%
def read_nifti_file(filepath):
    """Read and load volume"""
    # Read file
    scan = nib.load(filepath)
    # Get raw data
    scan = scan.get_fdata(caching='unchanged')
    return scan


def normalize(volume, min_normalize, max_normalize):
  """Normalize the volume"""
  min = min_normalize #-1000
  max = max_normalize #400
  volume[volume < min] = min
  volume[volume > max] = max
  volume = (volume - min) / (max - min)
  volume = volume.astype("float32")
  return volume


def resize_volume(img):
  # Esta conversión de 3D a 2D se puede hacer antes o después del zoom.
  if reduccion == 'SUM':
    # Sumamos la 3ra dimensión.
    img = np.sum(img,axis=-1)
  if reduccion == 'MEAN':
    # Promediamos la 3ra dimensión.
    img = np.mean(img,axis=-1)
  if reduccion == 'MAX':
    # Promediamos la 3ra dimensión.
    img = np.max(img,axis=-1)

  """Resize across z-axis"""
  # Set the desired depth
  desired_width = 128
  desired_height = 128
  # Get current depth
  current_width = img.shape[0]
  current_height = img.shape[1]
  # Compute depth factor
  width = current_width / desired_width
  height = current_height / desired_height
  width_factor = 1 / width
  height_factor = 1 / height

  # Resize across z-axis
  tic = time.time()
  img = ndimage.zoom(img, (width_factor, height_factor), order=1)
  #print("     Tiempo zoom:",time.time() - tic)

  # Rotate
  tic = time.time()
  img = ndimage.rotate(img, 90, reshape=False)
  #print("     Tiempo rotate:",time.time() - tic)

  return img

# %%
def rotate(volume):
    # define some rotation angles
    angles = [-20, -10, -5, 5, 10, 20]
    # pick angles at random
    angle = random.choice(angles)
    # rotate volume
    volume = ndimage.rotate(volume, angle, reshape=False)
    volume[volume < 0] = 0
    volume[volume > 1] = 1
    return volume

# %%
def get_augmentation(patch_size):
    return Compose([
        #Resize(patch_size, interpolation=1, resize_type=0, always_apply=True, p=1.0),
        Flip(0, p=1), # Eje X
        Flip(1, p=1), # Eje Y
        Flip(2, p=1), # Eje Z
        GaussianNoise(var_limit=(0.0001, 0.0005), p=1),
        ColorJitter(brightness=(1,3),contrast=(0.4,0.8),saturation=0,hue=0, p=1),
    ], p=1)

def augmentor(img):
    aug = get_augmentation((128,128,64))
    data = {'image': img}
    aug_data = aug(**data)
    img = aug_data['image']
    return np.ndarray.astype(img , np.float32)

# %%
def load_arrays(path, training_):

    #print(path.numpy().decode())
    tic1 = time.time()

    # Lectura CT
    tic = time.time()
    image_ = nib.load(path.numpy().decode())
    #print("Tiempo lectura:",time.time() - tic)

    # Convertirlo en array
    tic = time.time()
    image_ = image_.get_fdata()
    #print("shape:",image_.shape)
    #print("Tiempo array:",time.time() - tic)

    # Aplicar función de estandarización número de cortes y rotación 90 grados
    tic = time.time()
    image = resize_volume(image_)[..., None]
    #print("Tiempo resize:",time.time() - tic)

    # Aplicar función normalización
    tic = time.time()
    image = normalize(image, min_normalize=min_ventana, max_normalize=max_ventana)
    #print("Tiempo normalizacion:",time.time() - tic)

    if training_:
        #print("Aplicando Data Augmentation************************************")

        # Aplicar rotación aleatoria
        tic = time.time()
        image = rotate(image)
        #print("Tiempo rotación aleatoria:",time.time() - tic)

        # Implementar data augmentation
        tic = time.time()
        #image = augmentor(image)
        #print("Tiempo aug:",time.time() - tic)

        # Limitando valores entre 0-1
        tic = time.time()
        #image = tf.clip_by_value(image, clip_value_min = 0, clip_value_max = 1)
        #print("Tiempo clip_by_value:",time.time() - tic)

    else:
        #print("Las tomografías se cargan solo con el resize y la normalización")

        #print("|| Tiempo total lectura tomografía: ", time.time() - tic1)
        #print("---")

        image = image


    return image#.reshape(image_.shape+(1,))

def tf_data_array(filenames1, labels, training_):
    [image,] = tf.py_function(func= load_arrays,  inp=[filenames1, training_], Tout=[tf.float32])
    image.set_shape((128,128,1))
    return image,  labels

# %%
def datasets_iteration(dataset_row, training=False):
    filename = dataset_row['path']
    labels = dataset_row['Label']
    dataset = tf.data.Dataset.from_tensor_slices((filename,labels))

    #print(dataset)

    if training:
        dataset = dataset.shuffle(len(dataset_row),seed=RANDOM)

    #Aplicamos todas las funciones de pre-procesamiento
    #dataset = dataset.map(tf_data_array).batch(BATCH_SIZE)#.prefetch(tf.data.AUTOTUNE)
    # dataset = dataset.map(tf_data_array).cache().batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    # dataset = dataset.map(tf_data_array, num_parallel_calls = 4).batch(BATCH_SIZE).cache().prefetch(tf.data.AUTOTUNE)
    # dataset = dataset.map(tf_data_array, num_parallel_calls = 4).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    # dataset = dataset.map(tf_data_array, num_parallel_calls = 4).batch(BATCH_SIZE).prefetch(1)
    dataset = dataset.map(partial(tf_data_array, training_ = training), num_parallel_calls = tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(2)

    # https://stackoverflow.com/questions/59228816/what-do-the-tensorflow-datasets-functions-cache-and-prefetch-do
    # https://stackoverflow.com/questions/63796936/what-is-the-proper-use-of-tensorflow-dataset-prefetch-and-cache-options
    # https://cs230.stanford.edu/blog/datapipeline/#best-practices
    return dataset

# %%
train_dataset = datasets_iteration(train_df,True)
test_dataset = datasets_iteration(test_df)
validation_dataset = datasets_iteration(valid_df)

# train_dataset = datasets_iteration(train_df.iloc[[5,6,7,8,9,290,291,292,293,294]],True)
# test_dataset = datasets_iteration(test_df.iloc[[5,6,7,8,9,79,80,81,82,83]])
# validation_dataset = datasets_iteration(valid_df.iloc[[5,6,7,8,9,40,41,42,43,44]])

# %%
validation_dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %% [markdown]
# ### Método una sola lectura

# %%
def process_scan(path, min_normalize, max_normalize):
    """Read and resize volume"""
    # Read scan
    volume = read_nifti_file(path)
    # Resize width, height and depth
    volume = resize_volume(volume)[..., None]
    # Normalize
    volume = normalize(volume, min_normalize=min_normalize, max_normalize=max_normalize)

    return volume

def data_augmentation(volume, training_):

    if training_:

        #print("Aplicando Data Augmentation************************************")

        # Aplicar rotación aleatoria
        tic = time.time()
        volume = rotate(volume)
        #print("Tiempo rotación aleatoria:",time.time() - tic)

        # Implementar data augmentation
        tic = time.time()
        # volume = augmentor(volume)
        #print("Tiempo aug:",time.time() - tic)

        # Limitando valores entre 0-1
        tic = time.time()
        # volume = tf.clip_by_value(volume, clip_value_min = 0, clip_value_max = 1)
        #print("Tiempo clip_by_value:",time.time() - tic)

    else:
        volume = volume

    return volume


def tf_data_array2(images, labels, training_):
    [image,] = tf.py_function(func= data_augmentation,  inp=[images, training_], Tout=[tf.float32])
    image.set_shape((128,128,1))
    return image,  labels

# %%
if reading_cts_tf == False:
  print("Leyendo CTs una sola vez")
  # Leyendo tomografías de entrenamiento
  print("Leyendo tomografías de entrenamiento")
  tic = time.time()
  x_train = np.array([process_scan(path, min_normalize= min_ventana, max_normalize=max_ventana) for path in train_df['path']])
  print("--- %s minutos ---" % ((time.time() - tic)/60))

  print("Leyendo tomografías de test")
  tic = time.time()
  x_test = np.array([process_scan(path, min_normalize= min_ventana, max_normalize=max_ventana) for path in test_df['path']])
  print("--- %s minutos ---" % ((time.time() - tic)/60))

  print("Leyendo tomografías de validación")
  tic = time.time()
  x_valid = np.array([process_scan(path, min_normalize= min_ventana, max_normalize=max_ventana) for path in valid_df['path']])
  print("--- %s minutos ---" % ((time.time() - tic)/60))
# Out:
# Leyendo CTs una sola vez
# Leyendo tomografías de entrenamiento
# --- 12.82797376314799 minutos ---
# Leyendo tomografías de test
# --- 3.1054054061571756 minutos ---
# Leyendo tomografías de validación
# --- 1.6712843855222066 minutos ---

# %%
# Validación Dimensión Arrays:
print(f"Dim x_train: {x_train.shape} -- Dim y_train: {len(train_df['path'])}. -- {Counter(train_df['Label'])}")
print(f"Dim x_train: {x_test.shape} -- Dim y_train: {len(test_df['path'])}. -- {Counter(test_df['Label'])}")
print(f"Dim x_train: {x_valid.shape} -- Dim y_train: {len(valid_df['path'])}. -- {Counter(valid_df['Label'])}")
# Out:
# Dim x_train: (295, 128, 128, 1) -- Dim y_train: 295. -- Counter({0: 177, 1: 118})
# Dim x_train: (84, 128, 128, 1) -- Dim y_train: 84. -- Counter({0: 50, 1: 34})
# Dim x_train: (45, 128, 128, 1) -- Dim y_train: 45. -- Counter({0: 27, 1: 18})

# %%
def datasets_iteration2(images, dataset_row, training=False):

    labels = dataset_row['Label']

    dataset = tf.data.Dataset.from_tensor_slices((images,labels))

    if training:
        dataset = dataset.shuffle(len(images),seed=RANDOM)

    dataset = dataset.map(partial(tf_data_array2, training_ = training), num_parallel_calls = tf.data.AUTOTUNE).batch(BATCH_SIZE)#.prefetch(1)

    #dataset = dataset.batch(BATCH_SIZE).prefetch(2)

    return dataset

# %%
if reading_cts_tf == False:
  print("Datasets creados con datasets_iteration2 ************")
  train_dataset = datasets_iteration2(x_train, train_df,True)
  test_dataset = datasets_iteration2(x_test, test_df)
  validation_dataset = datasets_iteration2(x_valid, valid_df)
else:
  print("Se mantiene el objeto TF para lectura de CTs según el batch")
# Out:
# Datasets creados con datasets_iteration2 ************

# %%
validation_dataset
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %% [markdown]
# ## Visualizamos algunas imágenes

# %% [markdown]
# ### Train

# %%
tic = time.time()
data = train_dataset.take(1) # Tomamos primer batch
data2 = list(data)

images, labels = data2[0]
images = images.numpy()
print("******* Tiempo total lectura batch: ", time.time() - tic)
# Out:
# ******* Tiempo total lectura batch:  0.055571794509887695

# %%
index_ct = 0
mensaje = f"CT Etiqueta: {labels.numpy()[index_ct]} "
print(mensaje)
img_print = images[index_ct]
label_print = labels.numpy()[index_ct]
fig = plt.figure(figsize=(10, 5))
columns = 10
rows = 7
depth_img = img_print.shape[2]

file_image_path = f'G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Imgs/TF_VF_Index{index_ct}_Rango{min_ventana}_{max_ventana}.png'
print(file_image_path)

plt.imshow(img_print)

# # ax enables access to manipulate each of subplots
# ax = []

# for i in range(1, depth_img+1):
#     img = np.squeeze(img_print[:, :, i-1])
#     #fig.add_subplot(rows, columns, i)
#     ax.append( fig.add_subplot(rows, columns, i))
#     ax[-1].set_title("depth:"+str(i))  # set title
#     plt.imshow(img, cmap='gray')
# plt.suptitle(mensaje)
# #plt.savefig(file_image_path)
# plt.show()
# Out:
# CT Etiqueta: 1
# G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Imgs/TF_VF_Index0_Rango-1000_0.png

# %% [markdown]
# ### Valid

# %%
tic = time.time()
data = validation_dataset.take(1) # Tomamos primer batch
data2 = list(data)

images, labels = data2[0]
images = images.numpy()
print("******* Tiempo total lectura batch: ", time.time() - tic)
# Out:
# ******* Tiempo total lectura batch:  0.015429019927978516

# %%
index_ct = 0
mensaje = f"CT Etiqueta: {labels.numpy()[index_ct]} "
print(mensaje)
img_print = images[index_ct]
label_print = labels.numpy()[index_ct]
fig = plt.figure(figsize=(10, 5))
columns = 10
rows = 7
depth_img = img_print.shape[2]

file_image_path = f'G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Imgs/TF_VF_Index{index_ct}_Rango{min_ventana}_{max_ventana}.png'
print(file_image_path)

plt.imshow(img_print)

# # ax enables access to manipulate each of subplots
# ax = []

# for i in range(1, depth_img+1):
#     img = np.squeeze(img_print[:, :, i-1])
#     #fig.add_subplot(rows, columns, i)
#     ax.append( fig.add_subplot(rows, columns, i))
#     ax[-1].set_title("depth:"+str(i))  # set title
#     plt.imshow(img, cmap='gray')
# plt.suptitle(mensaje)
# #plt.savefig(file_image_path)
# plt.show()
# Out:
# CT Etiqueta: 0
# G:/Mi unidad/Maestria/Tesis/Bayesian_NN/Data/Imgs/TF_VF_Index0_Rango-1000_0.png

# %% [markdown]
# # Modelo 1 - Data Augmentation Keras

# %%
def get_model(width=128, height=128):
    """Build a 3D convolutional neural network model."""

    inputs = keras.Input((width, height, 1))

    x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(inputs)
    x = layers.MaxPool2D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool2D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool2D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool2D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalMaxPooling2D()(x)
    x = layers.Dense(units=256, activation="relu")(x)
    x = layers.Dropout(0.2)(x)

    outputs = layers.Dense(units=1, activation="sigmoid")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="2dcnn")
    return model


# Build model.
model = get_model(width=128, height=128)
model.summary()
# Out:
# Model: "2dcnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  conv2d (Conv2D)             (None, 126, 126, 128)     1280
#
#  max_pooling2d (MaxPooling2  (None, 63, 63, 128)       0
#  D)
#
#  batch_normalization (Batch  (None, 63, 63, 128)       512
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 128)       147584
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 128)       0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 30, 30, 128)       512
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 256)       295168
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 256)       0
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 14, 14, 256)       1024
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 512)       1180160
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 512)         0
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 6, 6, 512)         2048
#  chNormalization)
#
#  global_max_pooling2d (Glob  (None, 512)               0
#  alMaxPooling2D)
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 1759873 (6.71 MB)
# Trainable params: 1757825 (6.71 MB)
# Non-trainable params: 2048 (8.00 KB)
# _________________________________________________________________

# %%
os.getcwd()
# Out:
# '/content'

# %%
if os.path.isfile(file_modelo):
  print(f"Ruta modelo existe!!!!!!!!!!!!!!!!!!!!!!!!!!!! {file_modelo}")
else:
  print(f"Se creará archivo: {file_modelo}")
# Out:
# Se creará archivo: /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MAX.h5

# %% [markdown]
# ## Compilar Modelo

# %%
tic = time.time()
# Compile model.
# initial_learning_rate = 0.0001
# lr_schedule = keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
# )

# reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min' ,factor=0.8,verbose=1,
#                               patience=5, min_lr=1e-6)

model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=initial_learning_rate),
    metrics=["acc", "BinaryIoU", "Recall"],
)

# Define callbacks.
checkpoint_cb = keras.callbacks.ModelCheckpoint(
    file_modelo,
    save_best_only=True, monitor = "val_loss", mode = "min", save_weights_only = True, verbose = 1,
)
early_stopping_cb = keras.callbacks.EarlyStopping(monitor="val_loss", mode = 'min', restore_best_weights = True, patience=30, verbose = 1)

# Train the model, doing validation at the end of each epoch
# epochs = 100
history = model.fit(
    train_dataset,
    validation_data=validation_dataset, #debería ser shuffle?
    epochs=epochs,
    verbose=1,
    callbacks=[checkpoint_cb, early_stopping_cb], #reduce_lr],
)
print("******* Tiempo total entrenamiento en minutos: ", (time.time() - tic)/60)
# Out:
# Epoch 1/150
# 148/148 [==============================] - ETA: 0s - loss: 1.1358 - acc: 0.4983 - binary_io_u: 0.3198 - recall: 0.3729
# Epoch 1: val_loss improved from inf to 0.67875, saving model to /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MAX.h5
# 148/148 [==============================] - 10s 17ms/step - loss: 1.1358 - acc: 0.4983 - binary_io_u: 0.3198 - recall: 0.3729 - val_loss: 0.6788 - val_acc: 0.6000 - val_binary_io_u: 0.3000 - val_recall: 0.0000e+00
# Epoch 2/150
# 148/148 [==============================] - ETA: 0s - loss: 1.0282 - acc: 0.4983 - binary_io_u: 0.3162 - recall: 0.3390
# Epoch 2: val_loss improved from 0.67875 to 0.67446, saving model to /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MAX.h5
# 148/148 [==============================] - 1s 10ms/step - loss: 1.0282 - acc: 0.4983 - binary_io_u: 0.3162 - recall: 0.3390 - val_loss: 0.6745 - val_acc: 0.5778 - val_binary_io_u: 0.3764 - val_recall: 0.3333
# Epoch 3/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.8650 - acc: 0.5476 - binary_io_u: 0.3641 - recall: 0.4237
# Epoch 3: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.8666 - acc: 0.5458 - binary_io_u: 0.3624 - recall: 0.4237 - val_loss: 0.9058 - val_acc: 0.4000 - val_binary_io_u: 0.2000 - val_recall: 1.0000
# Epoch 4/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.8286 - acc: 0.5810 - binary_io_u: 0.3833 - recall: 0.3628
# Epoch 4: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.8406 - acc: 0.5695 - binary_io_u: 0.3757 - recall: 0.3729 - val_loss: 0.8181 - val_acc: 0.4667 - val_binary_io_u: 0.2862 - val_recall: 0.8889
# Epoch 5/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.7362 - acc: 0.6303 - binary_io_u: 0.4274 - recall: 0.3874
# Epoch 5: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.7317 - acc: 0.6373 - binary_io_u: 0.4396 - recall: 0.4153 - val_loss: 0.7579 - val_acc: 0.4667 - val_binary_io_u: 0.3042 - val_recall: 0.5556
# Epoch 6/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.7787 - acc: 0.5714 - binary_io_u: 0.3762 - recall: 0.3675
# Epoch 6: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.7776 - acc: 0.5729 - binary_io_u: 0.3784 - recall: 0.3729 - val_loss: 0.7138 - val_acc: 0.5111 - val_binary_io_u: 0.3312 - val_recall: 0.3889
# Epoch 7/150
# 148/148 [==============================] - ETA: 0s - loss: 0.6727 - acc: 0.6203 - binary_io_u: 0.4207 - recall: 0.3898
# Epoch 7: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6727 - acc: 0.6203 - binary_io_u: 0.4207 - recall: 0.3898 - val_loss: 0.7381 - val_acc: 0.5111 - val_binary_io_u: 0.3420 - val_recall: 0.7222
# Epoch 8/150
# 144/148 [============================>.] - ETA: 0s - loss: 0.6945 - acc: 0.6007 - binary_io_u: 0.4077 - recall: 0.4174
# Epoch 8: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6987 - acc: 0.6000 - binary_io_u: 0.4057 - recall: 0.4068 - val_loss: 0.8387 - val_acc: 0.6000 - val_binary_io_u: 0.3000 - val_recall: 0.0000e+00
# Epoch 9/150
# 148/148 [==============================] - ETA: 0s - loss: 0.7171 - acc: 0.5661 - binary_io_u: 0.3729 - recall: 0.3729
# Epoch 9: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.7171 - acc: 0.5661 - binary_io_u: 0.3729 - recall: 0.3729 - val_loss: 0.7423 - val_acc: 0.6000 - val_binary_io_u: 0.3218 - val_recall: 0.0556
# Epoch 10/150
# 144/148 [============================>.] - ETA: 0s - loss: 0.6806 - acc: 0.5799 - binary_io_u: 0.3631 - recall: 0.2522
# Epoch 10: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6801 - acc: 0.5831 - binary_io_u: 0.3677 - recall: 0.2627 - val_loss: 0.6996 - val_acc: 0.5556 - val_binary_io_u: 0.3726 - val_recall: 0.4444
# Epoch 11/150
# 148/148 [==============================] - ETA: 0s - loss: 0.6741 - acc: 0.6034 - binary_io_u: 0.3901 - recall: 0.2966
# Epoch 11: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6741 - acc: 0.6034 - binary_io_u: 0.3901 - recall: 0.2966 - val_loss: 0.6954 - val_acc: 0.5778 - val_binary_io_u: 0.3091 - val_recall: 0.0556
# Epoch 12/150
# 146/148 [============================>.] - ETA: 0s - loss: 0.6681 - acc: 0.6130 - binary_io_u: 0.4001 - recall: 0.3077
# Epoch 12: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6674 - acc: 0.6136 - binary_io_u: 0.3999 - recall: 0.3051 - val_loss: 0.7076 - val_acc: 0.5556 - val_binary_io_u: 0.2965 - val_recall: 0.0556
# Epoch 13/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.6558 - acc: 0.5793 - binary_io_u: 0.3722 - recall: 0.2991
# Epoch 13: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6604 - acc: 0.5763 - binary_io_u: 0.3705 - recall: 0.3051 - val_loss: 0.6908 - val_acc: 0.4889 - val_binary_io_u: 0.2839 - val_recall: 0.1667
# Epoch 14/150
# 144/148 [============================>.] - ETA: 0s - loss: 0.6703 - acc: 0.6215 - binary_io_u: 0.4175 - recall: 0.3621
# Epoch 14: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6712 - acc: 0.6203 - binary_io_u: 0.4150 - recall: 0.3559 - val_loss: 0.7449 - val_acc: 0.6000 - val_binary_io_u: 0.3000 - val_recall: 0.0000e+00
# Epoch 15/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.6619 - acc: 0.6103 - binary_io_u: 0.4047 - recall: 0.3478
# Epoch 15: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6695 - acc: 0.6068 - binary_io_u: 0.4022 - recall: 0.3475 - val_loss: 0.7399 - val_acc: 0.6000 - val_binary_io_u: 0.3407 - val_recall: 0.1111
# Epoch 16/150
# 146/148 [============================>.] - ETA: 0s - loss: 0.7225 - acc: 0.5788 - binary_io_u: 0.3800 - recall: 0.3504
# Epoch 16: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.7217 - acc: 0.5797 - binary_io_u: 0.3801 - recall: 0.3475 - val_loss: 0.6978 - val_acc: 0.6222 - val_binary_io_u: 0.3346 - val_recall: 0.0556
# Epoch 17/150
# 143/148 [===========================>..] - ETA: 0s - loss: 0.6531 - acc: 0.5839 - binary_io_u: 0.3568 - recall: 0.2124
# Epoch 17: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6604 - acc: 0.5763 - binary_io_u: 0.3499 - recall: 0.2034 - val_loss: 0.6830 - val_acc: 0.6222 - val_binary_io_u: 0.3346 - val_recall: 0.0556
# Epoch 18/150
# 146/148 [============================>.] - ETA: 0s - loss: 0.6341 - acc: 0.6027 - binary_io_u: 0.4049 - recall: 0.3814
# Epoch 18: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6309 - acc: 0.6068 - binary_io_u: 0.4078 - recall: 0.3814 - val_loss: 0.7264 - val_acc: 0.6000 - val_binary_io_u: 0.3000 - val_recall: 0.0000e+00
# Epoch 19/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.6425 - acc: 0.5952 - binary_io_u: 0.3635 - recall: 0.2051
# Epoch 19: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6439 - acc: 0.5932 - binary_io_u: 0.3619 - recall: 0.2034 - val_loss: 0.7037 - val_acc: 0.6222 - val_binary_io_u: 0.3346 - val_recall: 0.0556
# Epoch 20/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.6617 - acc: 0.6056 - binary_io_u: 0.4006 - recall: 0.3482
# Epoch 20: val_loss did not improve from 0.67446
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6677 - acc: 0.5966 - binary_io_u: 0.3910 - recall: 0.3305 - val_loss: 0.6798 - val_acc: 0.5333 - val_binary_io_u: 0.2841 - val_recall: 0.0556
# Epoch 21/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.6568 - acc: 0.5986 - binary_io_u: 0.3882 - recall: 0.3077
# Epoch 21: val_loss improved from 0.67446 to 0.66689, saving model to /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MAX.h5
# 148/148 [==============================] - 2s 14ms/step - loss: 0.6563 - acc: 0.6000 - binary_io_u: 0.3907 - recall: 0.3136 - val_loss: 0.6669 - val_acc: 0.5778 - val_binary_io_u: 0.3267 - val_recall: 0.1111
# Epoch 22/150
# 148/148 [==============================] - ETA: 0s - loss: 0.6314 - acc: 0.6475 - binary_io_u: 0.4585 - recall: 0.4831
# Epoch 22: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6314 - acc: 0.6475 - binary_io_u: 0.4585 - recall: 0.4831 - val_loss: 0.7858 - val_acc: 0.6000 - val_binary_io_u: 0.3000 - val_recall: 0.0000e+00
# Epoch 23/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.6287 - acc: 0.6310 - binary_io_u: 0.4351 - recall: 0.4261
# Epoch 23: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6323 - acc: 0.6271 - binary_io_u: 0.4305 - recall: 0.4153 - val_loss: 0.7675 - val_acc: 0.6000 - val_binary_io_u: 0.3000 - val_recall: 0.0000e+00
# Epoch 24/150
# 148/148 [==============================] - ETA: 0s - loss: 0.6761 - acc: 0.5627 - binary_io_u: 0.3557 - recall: 0.2797
# Epoch 24: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6761 - acc: 0.5627 - binary_io_u: 0.3557 - recall: 0.2797 - val_loss: 0.6909 - val_acc: 0.5333 - val_binary_io_u: 0.3239 - val_recall: 0.2222
# Epoch 25/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.6325 - acc: 0.6479 - binary_io_u: 0.4413 - recall: 0.3750
# Epoch 25: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6388 - acc: 0.6407 - binary_io_u: 0.4324 - recall: 0.3559 - val_loss: 0.7675 - val_acc: 0.6000 - val_binary_io_u: 0.3000 - val_recall: 0.0000e+00
# Epoch 26/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.6121 - acc: 0.6586 - binary_io_u: 0.4459 - recall: 0.3448
# Epoch 26: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6154 - acc: 0.6542 - binary_io_u: 0.4408 - recall: 0.3390 - val_loss: 0.7493 - val_acc: 0.6000 - val_binary_io_u: 0.3218 - val_recall: 0.0556
# Epoch 27/150
# 146/148 [============================>.] - ETA: 0s - loss: 0.6320 - acc: 0.6096 - binary_io_u: 0.4080 - recall: 0.3675
# Epoch 27: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6314 - acc: 0.6102 - binary_io_u: 0.4079 - recall: 0.3644 - val_loss: 0.6901 - val_acc: 0.6222 - val_binary_io_u: 0.4125 - val_recall: 0.3333
# Epoch 28/150
# 146/148 [============================>.] - ETA: 0s - loss: 0.6159 - acc: 0.6336 - binary_io_u: 0.4369 - recall: 0.4153
# Epoch 28: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6161 - acc: 0.6305 - binary_io_u: 0.4335 - recall: 0.4153 - val_loss: 0.6917 - val_acc: 0.6667 - val_binary_io_u: 0.4617 - val_recall: 0.3889
# Epoch 29/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.6261 - acc: 0.6122 - binary_io_u: 0.3991 - recall: 0.3077
# Epoch 29: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6268 - acc: 0.6102 - binary_io_u: 0.3972 - recall: 0.3051 - val_loss: 0.7559 - val_acc: 0.6000 - val_binary_io_u: 0.3218 - val_recall: 0.0556
# Epoch 30/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.6264 - acc: 0.6190 - binary_io_u: 0.4156 - recall: 0.3644
# Epoch 30: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6260 - acc: 0.6203 - binary_io_u: 0.4165 - recall: 0.3644 - val_loss: 0.7458 - val_acc: 0.6000 - val_binary_io_u: 0.3000 - val_recall: 0.0000e+00
# Epoch 31/150
# 148/148 [==============================] - ETA: 0s - loss: 0.6397 - acc: 0.6305 - binary_io_u: 0.4360 - recall: 0.4322
# Epoch 31: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6397 - acc: 0.6305 - binary_io_u: 0.4360 - recall: 0.4322 - val_loss: 0.7095 - val_acc: 0.5111 - val_binary_io_u: 0.3086 - val_recall: 0.2222
# Epoch 32/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.6052 - acc: 0.6514 - binary_io_u: 0.4535 - recall: 0.4324
# Epoch 32: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6099 - acc: 0.6441 - binary_io_u: 0.4457 - recall: 0.4153 - val_loss: 0.7199 - val_acc: 0.5111 - val_binary_io_u: 0.3176 - val_recall: 0.2778
# Epoch 33/150
# 148/148 [==============================] - ETA: 0s - loss: 0.6094 - acc: 0.6271 - binary_io_u: 0.4266 - recall: 0.3898
# Epoch 33: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6094 - acc: 0.6271 - binary_io_u: 0.4266 - recall: 0.3898 - val_loss: 0.7577 - val_acc: 0.6222 - val_binary_io_u: 0.3346 - val_recall: 0.0556
# Epoch 34/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.6031 - acc: 0.6429 - binary_io_u: 0.4474 - recall: 0.4359
# Epoch 34: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6035 - acc: 0.6407 - binary_io_u: 0.4452 - recall: 0.4322 - val_loss: 0.7454 - val_acc: 0.4222 - val_binary_io_u: 0.2604 - val_recall: 0.3333
# Epoch 35/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.5919 - acc: 0.7042 - binary_io_u: 0.5158 - recall: 0.4870
# Epoch 35: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5905 - acc: 0.7017 - binary_io_u: 0.5130 - recall: 0.4915 - val_loss: 0.7422 - val_acc: 0.5111 - val_binary_io_u: 0.2981 - val_recall: 0.1667
# Epoch 36/150
# 144/148 [============================>.] - ETA: 0s - loss: 0.6041 - acc: 0.6528 - binary_io_u: 0.4651 - recall: 0.4872
# Epoch 36: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6011 - acc: 0.6542 - binary_io_u: 0.4650 - recall: 0.4831 - val_loss: 0.7493 - val_acc: 0.4667 - val_binary_io_u: 0.2698 - val_recall: 0.1667
# Epoch 37/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.6227 - acc: 0.6514 - binary_io_u: 0.4535 - recall: 0.4211
# Epoch 37: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6208 - acc: 0.6576 - binary_io_u: 0.4608 - recall: 0.4322 - val_loss: 0.7440 - val_acc: 0.6222 - val_binary_io_u: 0.3346 - val_recall: 0.0556
# Epoch 38/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.6049 - acc: 0.6565 - binary_io_u: 0.4513 - recall: 0.3814
# Epoch 38: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6053 - acc: 0.6542 - binary_io_u: 0.4491 - recall: 0.3814 - val_loss: 0.7396 - val_acc: 0.5333 - val_binary_io_u: 0.3613 - val_recall: 0.7778
# Epoch 39/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.5953 - acc: 0.6310 - binary_io_u: 0.4387 - recall: 0.4522
# Epoch 39: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5969 - acc: 0.6305 - binary_io_u: 0.4384 - recall: 0.4492 - val_loss: 0.6923 - val_acc: 0.5556 - val_binary_io_u: 0.3394 - val_recall: 0.2222
# Epoch 40/150
# 148/148 [==============================] - ETA: 0s - loss: 0.6056 - acc: 0.6508 - binary_io_u: 0.4583 - recall: 0.4576
# Epoch 40: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6056 - acc: 0.6508 - binary_io_u: 0.4583 - recall: 0.4576 - val_loss: 0.6897 - val_acc: 0.6000 - val_binary_io_u: 0.3942 - val_recall: 0.3333
# Epoch 41/150
# 146/148 [============================>.] - ETA: 0s - loss: 0.6057 - acc: 0.6815 - binary_io_u: 0.4856 - recall: 0.4444
# Epoch 41: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6057 - acc: 0.6814 - binary_io_u: 0.4847 - recall: 0.4407 - val_loss: 0.7411 - val_acc: 0.4667 - val_binary_io_u: 0.3042 - val_recall: 0.5556
# Epoch 42/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.6214 - acc: 0.6138 - binary_io_u: 0.4318 - recall: 0.5259
# Epoch 42: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.6178 - acc: 0.6169 - binary_io_u: 0.4347 - recall: 0.5254 - val_loss: 0.7338 - val_acc: 0.6000 - val_binary_io_u: 0.3407 - val_recall: 0.1111
# Epoch 43/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.5829 - acc: 0.6531 - binary_io_u: 0.4541 - recall: 0.4153
# Epoch 43: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5820 - acc: 0.6542 - binary_io_u: 0.4549 - recall: 0.4153 - val_loss: 0.7683 - val_acc: 0.5111 - val_binary_io_u: 0.2981 - val_recall: 0.1667
# Epoch 44/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.5806 - acc: 0.6937 - binary_io_u: 0.5075 - recall: 0.5133
# Epoch 44: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5788 - acc: 0.6983 - binary_io_u: 0.5143 - recall: 0.5254 - val_loss: 0.7714 - val_acc: 0.5333 - val_binary_io_u: 0.2841 - val_recall: 0.0556
# Epoch 45/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.5754 - acc: 0.7148 - binary_io_u: 0.5355 - recall: 0.5727
# Epoch 45: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5987 - acc: 0.6983 - binary_io_u: 0.5154 - recall: 0.5339 - val_loss: 1.1063 - val_acc: 0.6000 - val_binary_io_u: 0.3000 - val_recall: 0.0000e+00
# Epoch 46/150
# 145/148 [============================>.] - ETA: 0s - loss: 0.5956 - acc: 0.6483 - binary_io_u: 0.4679 - recall: 0.5603
# Epoch 46: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5960 - acc: 0.6475 - binary_io_u: 0.4662 - recall: 0.5508 - val_loss: 0.7143 - val_acc: 0.4444 - val_binary_io_u: 0.2463 - val_recall: 0.1111
# Epoch 47/150
# 147/148 [============================>.] - ETA: 0s - loss: 0.5728 - acc: 0.6973 - binary_io_u: 0.5167 - recall: 0.5508
# Epoch 47: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5738 - acc: 0.6949 - binary_io_u: 0.5140 - recall: 0.5508 - val_loss: 0.8722 - val_acc: 0.6000 - val_binary_io_u: 0.3218 - val_recall: 0.0556
# Epoch 48/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.5956 - acc: 0.6761 - binary_io_u: 0.4836 - recall: 0.4775
# Epoch 48: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5899 - acc: 0.6881 - binary_io_u: 0.5016 - recall: 0.5085 - val_loss: 0.7828 - val_acc: 0.5111 - val_binary_io_u: 0.3312 - val_recall: 0.8889
# Epoch 49/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.5548 - acc: 0.7113 - binary_io_u: 0.5339 - recall: 0.5702
# Epoch 49: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5521 - acc: 0.7153 - binary_io_u: 0.5387 - recall: 0.5763 - val_loss: 0.8605 - val_acc: 0.5333 - val_binary_io_u: 0.3419 - val_recall: 0.3333
# Epoch 50/150
# 142/148 [===========================>..] - ETA: 0s - loss: 0.5564 - acc: 0.7113 - binary_io_u: 0.5378 - recall: 0.6000
# Epoch 50: val_loss did not improve from 0.66689
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5490 - acc: 0.7220 - binary_io_u: 0.5499 - recall: 0.6102 - val_loss: 0.8050 - val_acc: 0.5778 - val_binary_io_u: 0.3420 - val_recall: 0.1667
# Epoch 51/150
# 148/148 [==============================] - ETA: 0s - loss: 0.5785 - acc: 0.6881 - binary_io_u: 0.5080 - recall: 0.5593
# Epoch 51: val_loss did not improve from 0.66689
# Restoring model weights from the end of the best epoch: 21.
# 148/148 [==============================] - 1s 9ms/step - loss: 0.5785 - acc: 0.6881 - binary_io_u: 0.5080 - recall: 0.5593 - val_loss: 0.8332 - val_acc: 0.4889 - val_binary_io_u: 0.2595 - val_recall: 0.0556
# Epoch 51: early stopping
# ******* Tiempo total entrenamiento en minutos:  1.3252131740252178

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, metric in enumerate(["acc", "loss"]):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 3))
ax = ax.ravel()

for i, metric in enumerate(["acc","binary_io_u", "recall"]):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'acc', 'binary_io_u', 'recall', 'val_loss', 'val_acc', 'val_binary_io_u', 'val_recall'])

# %%
file_history
# Out:
# '/content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/History_Modelo_Keras_Arch_W4_V1_Optimizado_2D_MAX'

# %%
with open(file_history, 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# Para leer https://stackoverflow.com/questions/41061457/keras-how-to-save-the-training-history-attribute-of-the-history-object

# %%
model.evaluate(validation_dataset, verbose=2)
# Out:
# 23/23 - 0s - loss: 0.6669 - acc: 0.5778 - binary_io_u: 0.3267 - recall: 0.1111 - 90ms/epoch - 4ms/step
# [0.6668898463249207,
#  0.5777778029441833,
#  0.32668882608413696,
#  0.1111111119389534]

# %%
# file_modelo2 = '/content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_3D_W4_V1.h5'
print(f"Leyendo pesos del modelo: {file_modelo}")
model.load_weights(file_modelo)
# Out:
# Leyendo pesos del modelo: /content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Modelo_Keras_Arch_W4_V1_Optimizado_2D_MAX.h5

# %%
model.evaluate(validation_dataset, verbose=2)
# Out:
# 23/23 - 0s - loss: 0.6669 - acc: 0.5778 - binary_io_u: 0.3267 - recall: 0.1111 - 118ms/epoch - 5ms/step
# [0.6668898463249207,
#  0.5777778029441833,
#  0.32668882608413696,
#  0.1111111119389534]

# %%
y_valid_estimado = model.predict(validation_dataset)
# Out:
# 23/23 [==============================] - 0s 3ms/step

# %%
y_valid_estimado
# Out:
# array([[0.26328534],
#        [0.16000468],
#        [0.10175394],
#        [0.18785189],
#        [0.40298793],
#        [0.32287255],
#        [0.4427377 ],
#        [0.44228575],
#        [0.5058404 ],
#        [0.16239406],
#        [0.38226402],
#        [0.49312067],
#        [0.4828323 ],
#        [0.3682031 ],
#        [0.4770081 ],
#        [0.07840276],
#        [0.42713386],
#        [0.31858122],
#        [0.5170561 ],
#        [0.14853443],
#        [0.38685876],
#        [0.42734683],
#        [0.4624909 ],
#        [0.3714882 ],
#        [0.51726866],
#        [0.21392639],
#        [0.35514784],
#        [0.45916557],
#        [0.5183586 ],
#        [0.43042457],
#        [0.4057296 ],
#        [0.11541485],
#        [0.3784329 ],
#        [0.32211828],
#        [0.24831368],
#        [0.38825226],
#        [0.36247104],
#        [0.33924407],
#        [0.46693823],
#        [0.4906886 ],
#        [0.26652625],
#        [0.41678804],
#        [0.49111733],
#        [0.6161512 ],
#        [0.32166883]], dtype=float32)

# %% [markdown]
# ## Calculando métricas del modelo

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(
    cm, classes,
    normalize = False,
    title = 'Matriz de Confusión',
    cmap = plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalizacion can be applied by setting 'normalize = True'
    """

    plt.imshow(cm,interpolation = 'nearest', cmap= cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks,classes,rotation = 45)
    plt.yticks(tick_marks,classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix without normalization')

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment = "center",
                 color = "white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel("Etiqueta Verdadera")
    plt.xlabel("Etiqueta Predicha")

def calcular_metricas(nombre_modelo, tipo_set, etiquetas_reales, etiquetas_estimadas, etiquetas_estimadas_prob):

    print("Tipo:",tipo_set)

    # accuracy: (tp + tn) / (p + n)
    accuracy = accuracy_score(etiquetas_reales, etiquetas_estimadas)
    print('Accuracy: %f' % accuracy)
    # precision tp / (tp + fp)
    precision = precision_score(etiquetas_reales, etiquetas_estimadas)
    print('Precision: %f' % precision)
    # recall: tp / (tp + fn)
    recall = recall_score(etiquetas_reales, etiquetas_estimadas)
    print('Recall: %f' % recall)
    # f1: 2 tp / (2 tp + fp + fn)
    f1 = f1_score(etiquetas_reales, etiquetas_estimadas)
    print('F1 score: %f' % f1)

    # kappa
    kappa = cohen_kappa_score(etiquetas_reales, etiquetas_estimadas)
    print('Cohens kappa: %f' % kappa)
    # ROC AUC
    auc = roc_auc_score(etiquetas_reales, etiquetas_estimadas_prob)
    print('ROC AUC: %f' % auc)
    # IoU
    iou = tf.keras.metrics.IoU(num_classes=2, target_class_ids=[1])
    iou.update_state(etiquetas_reales, etiquetas_estimadas, sample_weight=None)
    iou = iou.result().numpy()
    # FBeta-Score
    beta = 2
    b2 = beta ** 2
    f_beta_score = (1 + b2) * (precision * recall) / (precision * b2 + recall)

    # confusion matrix
    matrix = confusion_matrix(etiquetas_reales, etiquetas_estimadas)
    print(matrix)

    # TP; FP; TN; FN
    TP = matrix[1][1]
    FP = matrix[0][1]
    TN = matrix[0][0]
    FN = matrix[1][0]


    df_modelo = pd.DataFrame(
        {"nombre_modelo" : [nombre_modelo],
        "tipo_set" : [tipo_set],
        "accuracy" : [accuracy],
        "precision" : [precision],
        "recall": [recall],
        "f1": [f1],
        "Cohens kappa": [kappa],
        "ROC AUC": [auc],
        "IoU": [iou],
        "FBetaScore": [f_beta_score],
        'TP':[TP],
        'FP':[FP],
        'TN':[TN],
        'FN':[FN],
        }
    )

    return df_modelo, matrix

# %%
if reading_cts_tf == False:
  print("Dataset seguimiento modelo con datasets_iteration2")
  p_train_dataset = datasets_iteration2(x_train, train_df)
else:
  print("Dataset seguimiento modelo con lectura repetitiva de los CTs por batches")
  p_train_dataset = datasets_iteration(train_df) # Para poder sacar el cálculo y las etiquetas

# p_test_dataset = datasets_iteration(test_df)
# p_validation_dataset = datasets_iteration(valid_df)

prueba_shuffle = datasets_iteration(valid_df.iloc[[25,26,27]], True)
prueba_shuffle

prueba_shuffle2 = datasets_iteration(valid_df.iloc[[25,26,27]])
prueba_shuffle2
# Out:
# Dataset seguimiento modelo con datasets_iteration2
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %%
etiquetas_shuffle = np.concatenate([y for x, y in prueba_shuffle], axis=0)
etiquetas_shuffle
# Out:
# array([0, 1, 0])

# %%
etiquetas_shuffle = np.concatenate([y for x, y in prueba_shuffle2], axis=0)
etiquetas_shuffle
# Out:
# array([0, 0, 1])

# %%
y_train = train_df['Label']
y_test = test_df['Label']
y_valid = valid_df['Label']

# %%
# Ajustando probabilidades para los datos. Se apunta a la probabilidad de 1 (positiva).
print("Train")
yhat_probs_train = model.predict(p_train_dataset, verbose=0)
print("Test")
yhat_probs_test = model.predict(test_dataset, verbose=0)
print("Valid")
yhat_probs_valid = model.predict(validation_dataset, verbose=0)


# Calculamos las clases
print("Clases")
yhat_classes_train = ((yhat_probs_train > 0.5)+0).ravel()
yhat_classes_test = ((yhat_probs_test > 0.5)+0).ravel()
yhat_classes_valid = ((yhat_probs_valid > 0.5)+0).ravel()

print("Shapes")
print("Shape train", yhat_classes_train.shape)
print("Shape test", yhat_classes_test.shape)
print("Shape valid", yhat_classes_valid.shape)
# Out:
# Train
# Test
# Valid
# Clases
# Shapes
# Shape train (295,)
# Shape test (84,)
# Shape valid (45,)

# %%
# Lo dejamos como 1d array
# yhat_probs_train = yhat_probs_train[:, 0]
# yhat_probs_test = yhat_probs_test[:, 0]
# yhat_probs_valid = yhat_probs_valid[:, 0]

#yhat_classes_train = yhat_classes_train[:, 0]
#yhat_classes_test = yhat_classes_test[:, 0]
#yhat_classes_valid = yhat_classes_valid[:, 0]

# %% [markdown]
# ### Métricas

# %%
metricas_train, cm_train = calcular_metricas(nombre_modelo = version_modelo,
                    tipo_set="Training",
                    etiquetas_reales=y_train,
                    etiquetas_estimadas=yhat_classes_train,
                    etiquetas_estimadas_prob=yhat_probs_train)

metricas_valid, cm_valid = calcular_metricas(nombre_modelo = version_modelo,
                    tipo_set="Validacion",
                    etiquetas_reales=y_valid,
                    etiquetas_estimadas=yhat_classes_valid,
                    etiquetas_estimadas_prob=yhat_probs_valid)

metricas_test, cm_test = calcular_metricas(nombre_modelo = version_modelo,
                    tipo_set="Test",
                    etiquetas_reales=y_test,
                    etiquetas_estimadas=yhat_classes_test,
                    etiquetas_estimadas_prob=yhat_probs_test)


resumen_modelo = pd.concat([metricas_train,metricas_valid,metricas_test]).reset_index(drop = True)
resumen_modelo
# Out:
# Tipo: Training
# Accuracy: 0.640678
# Precision: 0.636364
# Recall: 0.237288
# F1 score: 0.345679
# Cohens kappa: 0.164038
# ROC AUC: 0.706646
# [[161  16]
#  [ 90  28]]
# Tipo: Validacion
# Accuracy: 0.577778
# Precision: 0.400000
# Recall: 0.111111
# F1 score: 0.173913
# Cohens kappa: 0.000000
# ROC AUC: 0.565844
# [[24  3]
#  [16  2]]
# Tipo: Test
# Accuracy: 0.630952
# Precision: 0.636364
# Recall: 0.205882
# F1 score: 0.311111
# Cohens kappa: 0.141161
# ROC AUC: 0.613529
# [[46  4]
#  [27  7]]
#                         nombre_modelo    tipo_set  accuracy  precision  \
# 0  Keras_Arch_W4_V1_Optimizado_2D_MAX    Training     0.641      0.636
# 1  Keras_Arch_W4_V1_Optimizado_2D_MAX  Validacion     0.578      0.400
# 2  Keras_Arch_W4_V1_Optimizado_2D_MAX        Test     0.631      0.636
#
#    recall    f1  Cohens kappa  ROC AUC   IoU  FBetaScore  TP  FP   TN  FN
# 0   0.237 0.346         0.164    0.707 0.209       0.271  28  16  161  90
# 1   0.111 0.174         0.000    0.566 0.095       0.130   2   3   24  16
# 2   0.206 0.311         0.141    0.614 0.184       0.238   7   4   46  27

# %%
r'{}{}'.format(ruta_modelo,f"{version_modelo}.xlsx")
# Out:
# '/content/gdrive/MyDrive/Maestria/Tesis/Bayesian_NN/Modelos_Colab/Keras_Arch_W4_V1_Optimizado_2D_MAX.xlsx'

# %%
resumen_modelo.to_excel(r'{}{}'.format(ruta_modelo,f"{version_modelo}.xlsx"), index = False)

# %%
etiquetas_vf = ['No Signos Neumonia','Signos Neumonia']

# %%
plot_confusion_matrix(cm = cm_train, classes = etiquetas_vf,title = "Confusion Matrix Neumonía")
# Out:
# Confusion matrix without normalization

# %%
plot_confusion_matrix(cm = cm_valid, classes = etiquetas_vf,title = "Confusion Matrix Neumonía")
# Out:
# Confusion matrix without normalization

# %%
plot_confusion_matrix(cm = cm_test, classes = etiquetas_vf,title = "Confusion Matrix Neumonía")
# Out:
# Confusion matrix without normalization

# %%
valid_df['Label'].value_counts()
# Out:
# Label
# 0    27
# 1    18
# Name: count, dtype: int64
